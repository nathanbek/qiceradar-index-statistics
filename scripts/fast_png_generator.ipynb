# %%
import geopandas as gpd
import pandas as pd
import os
import fiona
from matplotlib_scalebar.scalebar import ScaleBar
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Define the paths
input_file_path = "./antarctic_index.gpkg"
map_path = "/Users/nathanbekele/Downloads/Quantarctica3/Miscellaneous/SimpleBasemap/ADD_DerivedLowresBasemap.shp"
output_folder = "./data3"
statistics_folder = "./data_statistics"

# Ensure the output folders exist
os.makedirs(output_folder, exist_ok=True)
os.makedirs(statistics_folder, exist_ok=True)

# Read the GeoPackage file into a GeoDataFrame
fp = gpd.read_file(input_file_path)

# Read the map shapefile
mp = gpd.read_file(map_path)

# Check if the 'Category' column exists
if 'Category' in mp.columns:
    # Define the colors for the categories
    category_colors = {
        'Ocean': '#a3bdd1',
        'Ice shelf': '#cfe1eb',
        'Land': '#f0f0f0',
        'Sub-antarctic_G': 'lightgreen',
        'Sub-antarctic_L': 'lightblue',
        'Ice tongue': 'lightgrey',
        'Rumple': 'yellow',
    }

    # Create a color column based on the 'Category' column
    mp['color'] = mp['Category'].map(category_colors).fillna('grey')  # Default to grey for undefined categories

    # Function to plot data on the colored basemap
    def plot_data_on_basemap(basemap, gdf, institution, filename):
        fig, ax = plt.subplots(figsize=(10, 10))

        # Set background color to white
        fig.patch.set_facecolor('white')
        ax.set_facecolor('white')

        # Plot basemap with custom colors
        basemap.plot(ax=ax, color=basemap['color'], edgecolor='black')

        # Define colors and labels based on availability
        availability_colors = {'u': '#fb9a99', 's': '#1f78bc', 'o': 'grey'}
        availability_labels = {'u': 'Unavailable', 's': 'Available', 'o': 'Outdated'}

        # Plot the data for the institution
        if not gdf.empty:
            for availability in ['s', 'u', 'o']:  # Ensure the order of plotting
                subset = gdf[gdf['availability'] == availability]
                if not subset.empty:
                    color = availability_colors.get(availability, 'darkgrey')
                    label = availability_labels.get(availability, 'Other')
                    subset.plot(ax=ax, color=color, markersize=0.55, linewidth=0.25, label=label)

        # Set limits to zoom in on Antarctica
        ax.set_xlim(-3e6, 3e6)
        ax.set_ylim(-3e6, 3e6)

        # Set equal aspect ratio for circular plot and remove axes
        ax.set_aspect('equal')
        ax.axis('off')

        # Add custom scale bar with "1000 km" label only
        scalebar = ScaleBar(1, location='lower right', units='km', dimension='si-length', label='1000 km', length_fraction=0.2)
        scalebar.dx = 1  # Set the distance to 1 unit of whatever is specified (km in this case)
        scalebar.label = '1000 km'  # Custom label

        ax.add_artist(scalebar)

        plt.title(f'{institution} Data Availability', fontsize=14)

        # Handle legend
        legend_patches = [Patch(color=color, label=availability_labels[availability]) for availability, color in availability_colors.items()]
        ax.legend(handles=legend_patches, loc='upper right', fontsize=8, title='Availability')

        # Draw a circular boundary
        circle = plt.Circle((0, 0), 3e6, transform=ax.transData, color='black', fill=False, linewidth=1)
        ax.add_artist(circle)

        # Save the plot to the data folder
        output_path = os.path.join(output_folder, filename)
        plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1)
        plt.close(fig)
        print(f"Saved map for {institution} to {output_path}")

    try:
        layers = fiona.listlayers(input_file_path)
        if not layers:
            raise ValueError("No layers found in the GeoPackage.")
        print("Layers in the GeoPackage:")
        print(layers)
    except Exception as e:
        print(f"Error listing layers in the GeoPackage: {e}")
        layers = []

    if not layers:
        print("No layers found or error in listing layers. Exiting.")
    else:
        # Create a dictionary to map institutions to layers
        institution_layers = {}

        # Populate the dictionary
        for layer in layers:
            try:
                gdf = gpd.read_file(input_file_path, layer=layer)  # Read the full layer
                if 'institution' in gdf.columns:
                    institutions = gdf['institution'].unique()
                    for institution in institutions:
                        if institution not in institution_layers:
                            institution_layers[institution] = []
                        institution_layers[institution].append(layer)
            except Exception as e:
                print(f"Error reading layer {layer}: {e}")

        print("Institution layers mapping:")
        print(institution_layers)

        # Create an overview GeoDataFrame
        overview_gdf = gpd.GeoDataFrame()

        # Iterate through each institution and create maps
        for institution, layers in institution_layers.items():
            institution_data = []

            print(f"\nProcessing institution: {institution}")

            for layer in layers:
                print(f"Checking layer: {layer}")
                try:
                    gdf = gpd.read_file(input_file_path, layer=layer)  # Read the full layer

                    if 'institution' in gdf.columns and institution in gdf['institution'].unique():
                        print(f"Layer '{layer}' contains '{institution}'.")
                        institution_data.append(gdf[gdf['institution'] == institution])
                    else:
                        print(f"Layer '{layer}' does not contain '{institution}' or does not have 'institution' column.")
                except Exception as e:
                    print(f"Error processing layer {layer}: {e}")

            # Combine all dataframes for the institution
            if institution_data:
                institution_gdf = gpd.GeoDataFrame(pd.concat(institution_data, ignore_index=True))
            else:
                institution_gdf = gpd.GeoDataFrame()

            # Ensure the CRS matches between the basemap and the GeoDataFrame
            if not institution_gdf.empty:
                institution_gdf = institution_gdf.to_crs(mp.crs)

            # Add to the overview GeoDataFrame
            if not institution_gdf.empty:
                overview_gdf = pd.concat([overview_gdf, institution_gdf])

            # Plot and save the aggregated data for the institution
            plot_data_on_basemap(mp, institution_gdf, institution, f'Antarctica_coverage_{institution}.png')

        # Ensure the CRS matches between the basemap and the overview GeoDataFrame
        if not overview_gdf.empty:
            overview_gdf = gpd.GeoDataFrame(overview_gdf).to_crs(mp.crs)

        # Plot and save the overview map
        plot_data_on_basemap(mp, overview_gdf, "Overview", 'Antarctica_coverage_overview.png')

        print("All maps have been created and saved to the data3 folder.")

else:
    print("The 'Category' column does not exist in the GeoDataFrame.")
# Out:
# Layers in the GeoPackage:
# ['AWI_1994_DML1', 'AWI_1995_DML2', 'AWI_1996_DML3', 'AWI_1997_DML4', 'AWI_1998_DML5', 'AWI_2000_DML6', 'AWI_2001_DML7', 'AWI_2002_DML8', 'AWI_2003_DML9', 'AWI_2004_DML10', 'AWI_2005_ANTSYSO', 'AWI_2007_ANTR', 'AWI_2013_GEA-IV', 'AWI_2014_Recovery-Glacier', 'AWI_2015_GEA-DML', 'AWI_2016_OIR', 'AWI_2018_ANIRES', 'AWI_2018_DML-Coast', 'AWI_2018_JURAS', 'AWI_2019_JURAS', 'BAS_1994_Evans', 'BAS_1998_Dufek', 'BAS_2001_Bailey-Slessor', 'BAS_2001_MAMOG', 'BAS_2002_TORUS', 'BAS_2007_Lake-Ellsworth', 'BAS_2007_Rutford', 'BAS_2007_TIGRIS', 'BAS_2008_Lake-Ellsworth', 'BAS_2009_FERRIGNO', 'BAS_2010_PIG', 'BAS_2011_Adelaide', 'BAS_2012_Castle', 'BAS_2013_ISTAR', 'BAS_2018_Thwaites', 'BAS_2019_Thwaites', 'BEDMAP1_BEDMAP1', 'BGR_1999_GANOVEX-VIII-Matusevich', 'BGR_1999_GANOVEX-VIII-Mertz', 'BGR_2002_PCMEGA', 'CECS_2006_Subglacial-Lake-CECs', 'INGV_1997_ITASE', 'INGV_1997_Talos-Dome', 'INGV_1999_Talos-Dome', 'INGV_2001_Talos-Dome', 'INGV_2003_Talos-Dome', 'KOPRI_2017_KRT1', 'KOPRI_2018_KRT2', 'LDEO_2007_Recovery-Lakes', 'LDEO_2015_ROSETTA', 'NASA_2002_ICEBRIDGE', 'NIPR_1992_JARE33', 'NIPR_1996_JARE37', 'NIPR_1999_JARE40', 'NIPR_2007_JARE49', 'NIPR_2007_JASE', 'NIPR_2012_JARE54', 'NIPR_2017_JARE59', 'NIPR_2018_JARE60', 'NPI_2008_BELISSIMA', 'NPI_2010_SRM', 'NPI_2012_ICERISES', 'NPI_2015_POLARGAP', 'NPI_2016_MADICE', 'PRIC_2004_CHINARE-21', 'PRIC_2007_CHINARE-24', 'PRIC_2015_CHA1', 'PRIC_2016_CHA2', 'PRIC_2017_CHA3', 'PRIC_2018_CHA4', 'RNRF_1971_Lambert-Amery', 'RNRF_1975_Filchner-Ronne', 'RNRF_1975_Lazarev', 'RNRF_2003_48RAEap5', 'RNRF_2003_AMSap5', 'RNRF_2004_49RAEap5', 'RNRF_2004_AMSap5', 'RNRF_2004_Mirny-Vostok', 'RNRF_2005_50RAEap5', 'RNRF_2005_AMSap5', 'RNRF_2006_51RAEap5', 'RNRF_2006_KV1-area', 'RNRF_2006_Komsom-Vostok', 'RNRF_2006_RAEap5', 'RNRF_2007_52RAEap5', 'RNRF_2007_AMSap5', 'RNRF_2007_Mirny-Vostok', 'RNRF_2008_53RAEap5', 'RNRF_2008_AMSap5', 'RNRF_2008_Vostok-Subglacial-Lake', 'RNRF_2009_RAEap5', 'RNRF_2010_RAE', 'RNRF_2011_RAE', 'RNRF_2013_RAE', 'RNRF_2013_Vostok-Progress', 'RNRF_2014_RAE', 'RNRF_2015_RAE', 'RNRF_2016_RAE', 'RNRF_2017_RAE', 'RNRF_2018_RAE', 'RNRF_2019_RAE', 'STOLAF_1994_Siple-Dome', 'STOLAF_2001_ITASE-Byrd-Ellsworth', 'STOLAF_2001_ITASE-Ellsworth', 'STOLAF_2002_ITASE-Byrd-South-Pole', 'STOLAF_2002_ITASE-Hercules-Dome', 'UCANTERBURY_2008_Darwin-Hatherton', 'ULB_2012_BEWISE', 'ULB_2012_ICECON', 'UTIG_1991_CASERTZ', 'UTIG_1998_West-Marie-Byrd-Land', 'UTIG_1999_SOAR-LVS-WLK', 'UTIG_2000_Robb-Glacier', 'UTIG_2008_ICECAP', 'UTIG_2009_Darwin-Hatherton', 'UTIG_2010_ICECAP', 'UTIG_2013_GIMBLE', 'UWASHINGTON_2018_South-Pole-Lake', 'AGAP', 'BBAS', 'FISS2015', 'FISS2016', 'GRADES_IMAGE', 'ICEGRAV', 'IMAFI', 'ITGC_2019', 'POLARGAP', 'WISE_ISODYN', '2002_Antarctica_P3chile', '2004_Antarctica_P3chile', '2005_Antarctica_GPRWAIS', '2009_Antarctica_DC8', '2009_Antarctica_TO', '2009_Antarctica_TO_Gambit', '2010_Antarctica_DC8', '2011_Antarctica_DC8', '2011_Antarctica_TO', '2012_Antarctica_DC8', '2013_Antarctica_Basler', '2013_Antarctica_P3', '2014_Antarctica_DC8', '2016_Antarctica_DC8', '2017_Antarctica_Basler', '2017_Antarctica_P3', '2018_Antarctica_DC8', '2018_Antarctica_Ground', '2019_Antarctica_GV', 'KRT1', 'AGAP_GAMBIT', 'AGASEA', 'DVD', 'EAGLE', 'ICECAP', 'LIV', 'OIA', 'STI', 'TAM', 'WAG', 'BAS_1969_1970', 'BAS_1971_1972', 'BAS_1974_1975', 'BAS_1980_1981', 'BAS_1982_1983', 'BAS_1983_1984', 'BAS_1984_1985', 'BAS_1985_1986', 'BAS_1987_1988', 'STANFORD_SPRI_NSF_TUD', 'institutions', 'data_formats', 'download_methods', 'campaigns', 'granules']
# Institution layers mapping:
# {'AWI': ['AWI_1994_DML1', 'AWI_1995_DML2', 'AWI_1996_DML3', 'AWI_1997_DML4', 'AWI_1998_DML5', 'AWI_2000_DML6', 'AWI_2001_DML7', 'AWI_2002_DML8', 'AWI_2003_DML9', 'AWI_2004_DML10', 'AWI_2005_ANTSYSO', 'AWI_2007_ANTR', 'AWI_2013_GEA-IV', 'AWI_2014_Recovery-Glacier', 'AWI_2015_GEA-DML', 'AWI_2016_OIR', 'AWI_2018_ANIRES', 'AWI_2018_DML-Coast', 'AWI_2018_JURAS', 'AWI_2019_JURAS'], 'BAS': ['BAS_1994_Evans', 'BAS_1998_Dufek', 'BAS_2001_Bailey-Slessor', 'BAS_2001_MAMOG', 'BAS_2002_TORUS', 'BAS_2007_Lake-Ellsworth', 'BAS_2007_Rutford', 'BAS_2007_TIGRIS', 'BAS_2008_Lake-Ellsworth', 'BAS_2009_FERRIGNO', 'BAS_2010_PIG', 'BAS_2011_Adelaide', 'BAS_2012_Castle', 'BAS_2013_ISTAR', 'BAS_2018_Thwaites', 'BAS_2019_Thwaites', 'AGAP', 'BBAS', 'FISS2015', 'FISS2016', 'GRADES_IMAGE', 'ICEGRAV', 'IMAFI', 'ITGC_2019', 'POLARGAP', 'WISE_ISODYN', 'BAS_1969_1970', 'BAS_1971_1972', 'BAS_1974_1975', 'BAS_1980_1981', 'BAS_1982_1983', 'BAS_1983_1984', 'BAS_1984_1985', 'BAS_1985_1986', 'BAS_1987_1988', 'campaigns'], 'BEDMAP1': ['BEDMAP1_BEDMAP1'], 'BGR': ['BGR_1999_GANOVEX-VIII-Matusevich', 'BGR_1999_GANOVEX-VIII-Mertz', 'BGR_2002_PCMEGA'], 'CECS': ['CECS_2006_Subglacial-Lake-CECs'], 'INGV': ['INGV_1997_ITASE', 'INGV_1997_Talos-Dome', 'INGV_1999_Talos-Dome', 'INGV_2001_Talos-Dome', 'INGV_2003_Talos-Dome'], 'KOPRI': ['KOPRI_2017_KRT1', 'KOPRI_2018_KRT2', 'KRT1'], 'LDEO': ['LDEO_2007_Recovery-Lakes', 'LDEO_2015_ROSETTA', 'AGAP_GAMBIT'], 'NASA': ['NASA_2002_ICEBRIDGE'], 'NIPR': ['NIPR_1992_JARE33', 'NIPR_1996_JARE37', 'NIPR_1999_JARE40', 'NIPR_2007_JARE49', 'NIPR_2007_JASE', 'NIPR_2012_JARE54', 'NIPR_2017_JARE59', 'NIPR_2018_JARE60'], 'NPI': ['NPI_2008_BELISSIMA', 'NPI_2010_SRM', 'NPI_2012_ICERISES', 'NPI_2015_POLARGAP', 'NPI_2016_MADICE'], 'PRIC': ['PRIC_2004_CHINARE-21', 'PRIC_2007_CHINARE-24', 'PRIC_2015_CHA1', 'PRIC_2016_CHA2', 'PRIC_2017_CHA3', 'PRIC_2018_CHA4'], 'RNRF': ['RNRF_1971_Lambert-Amery', 'RNRF_1975_Filchner-Ronne', 'RNRF_1975_Lazarev', 'RNRF_2003_48RAEap5', 'RNRF_2003_AMSap5', 'RNRF_2004_49RAEap5', 'RNRF_2004_AMSap5', 'RNRF_2004_Mirny-Vostok', 'RNRF_2005_50RAEap5', 'RNRF_2005_AMSap5', 'RNRF_2006_51RAEap5', 'RNRF_2006_KV1-area', 'RNRF_2006_Komsom-Vostok', 'RNRF_2006_RAEap5', 'RNRF_2007_52RAEap5', 'RNRF_2007_AMSap5', 'RNRF_2007_Mirny-Vostok', 'RNRF_2008_53RAEap5', 'RNRF_2008_AMSap5', 'RNRF_2008_Vostok-Subglacial-Lake', 'RNRF_2009_RAEap5', 'RNRF_2010_RAE', 'RNRF_2011_RAE', 'RNRF_2013_RAE', 'RNRF_2013_Vostok-Progress', 'RNRF_2014_RAE', 'RNRF_2015_RAE', 'RNRF_2016_RAE', 'RNRF_2017_RAE', 'RNRF_2018_RAE', 'RNRF_2019_RAE'], 'STOLAF': ['STOLAF_1994_Siple-Dome', 'STOLAF_2001_ITASE-Byrd-Ellsworth', 'STOLAF_2001_ITASE-Ellsworth', 'STOLAF_2002_ITASE-Byrd-South-Pole', 'STOLAF_2002_ITASE-Hercules-Dome'], 'UCANTERBURY': ['UCANTERBURY_2008_Darwin-Hatherton'], 'ULB': ['ULB_2012_BEWISE', 'ULB_2012_ICECON'], 'UTIG': ['UTIG_1991_CASERTZ', 'UTIG_1998_West-Marie-Byrd-Land', 'UTIG_1999_SOAR-LVS-WLK', 'UTIG_2000_Robb-Glacier', 'UTIG_2008_ICECAP', 'UTIG_2009_Darwin-Hatherton', 'UTIG_2010_ICECAP', 'UTIG_2013_GIMBLE', 'AGASEA', 'EAGLE', 'ICECAP', 'OIA'], 'UWASHINGTON': ['UWASHINGTON_2018_South-Pole-Lake'], 'CRESIS': ['2002_Antarctica_P3chile', '2004_Antarctica_P3chile', '2005_Antarctica_GPRWAIS', '2009_Antarctica_DC8', '2009_Antarctica_TO', '2009_Antarctica_TO_Gambit', '2010_Antarctica_DC8', '2011_Antarctica_DC8', '2011_Antarctica_TO', '2012_Antarctica_DC8', '2013_Antarctica_Basler', '2013_Antarctica_P3', '2014_Antarctica_DC8', '2016_Antarctica_DC8', '2017_Antarctica_Basler', '2017_Antarctica_P3', '2018_Antarctica_DC8', '2018_Antarctica_Ground', '2019_Antarctica_GV'], 'STANFORD': ['STANFORD_SPRI_NSF_TUD']}
#
# Processing institution: AWI
# Checking layer: AWI_1994_DML1
# Layer 'AWI_1994_DML1' contains 'AWI'.
# Checking layer: AWI_1995_DML2
# Layer 'AWI_1995_DML2' contains 'AWI'.
# Checking layer: AWI_1996_DML3
# Layer 'AWI_1996_DML3' contains 'AWI'.
# Checking layer: AWI_1997_DML4
# Layer 'AWI_1997_DML4' contains 'AWI'.
# Checking layer: AWI_1998_DML5
# Layer 'AWI_1998_DML5' contains 'AWI'.
# Checking layer: AWI_2000_DML6
# Layer 'AWI_2000_DML6' contains 'AWI'.
# Checking layer: AWI_2001_DML7
# Layer 'AWI_2001_DML7' contains 'AWI'.
# Checking layer: AWI_2002_DML8
# Layer 'AWI_2002_DML8' contains 'AWI'.
# Checking layer: AWI_2003_DML9
# Layer 'AWI_2003_DML9' contains 'AWI'.
# Checking layer: AWI_2004_DML10
# Layer 'AWI_2004_DML10' contains 'AWI'.
# Checking layer: AWI_2005_ANTSYSO
# Layer 'AWI_2005_ANTSYSO' contains 'AWI'.
# Checking layer: AWI_2007_ANTR
# Layer 'AWI_2007_ANTR' contains 'AWI'.
# Checking layer: AWI_2013_GEA-IV
# Layer 'AWI_2013_GEA-IV' contains 'AWI'.
# Checking layer: AWI_2014_Recovery-Glacier
# Layer 'AWI_2014_Recovery-Glacier' contains 'AWI'.
# Checking layer: AWI_2015_GEA-DML
# Layer 'AWI_2015_GEA-DML' contains 'AWI'.
# Checking layer: AWI_2016_OIR
# Layer 'AWI_2016_OIR' contains 'AWI'.
# Checking layer: AWI_2018_ANIRES
# Layer 'AWI_2018_ANIRES' contains 'AWI'.
# Checking layer: AWI_2018_DML-Coast
# Layer 'AWI_2018_DML-Coast' contains 'AWI'.
# Checking layer: AWI_2018_JURAS
# Layer 'AWI_2018_JURAS' contains 'AWI'.
# Checking layer: AWI_2019_JURAS
# Layer 'AWI_2019_JURAS' contains 'AWI'.
# Saved map for AWI to ./data3/Antarctica_coverage_AWI.png
#
# Processing institution: BAS
# Checking layer: BAS_1994_Evans
# Layer 'BAS_1994_Evans' contains 'BAS'.
# Checking layer: BAS_1998_Dufek
# Layer 'BAS_1998_Dufek' contains 'BAS'.
# Checking layer: BAS_2001_Bailey-Slessor
# Layer 'BAS_2001_Bailey-Slessor' contains 'BAS'.
# Checking layer: BAS_2001_MAMOG
# Layer 'BAS_2001_MAMOG' contains 'BAS'.
# Checking layer: BAS_2002_TORUS
# Layer 'BAS_2002_TORUS' contains 'BAS'.
# Checking layer: BAS_2007_Lake-Ellsworth
# Layer 'BAS_2007_Lake-Ellsworth' contains 'BAS'.
# Checking layer: BAS_2007_Rutford
# Layer 'BAS_2007_Rutford' contains 'BAS'.
# Checking layer: BAS_2007_TIGRIS
# Layer 'BAS_2007_TIGRIS' contains 'BAS'.
# Checking layer: BAS_2008_Lake-Ellsworth
# Layer 'BAS_2008_Lake-Ellsworth' contains 'BAS'.
# Checking layer: BAS_2009_FERRIGNO
# Layer 'BAS_2009_FERRIGNO' contains 'BAS'.
# Checking layer: BAS_2010_PIG
# Layer 'BAS_2010_PIG' contains 'BAS'.
# Checking layer: BAS_2011_Adelaide
# Layer 'BAS_2011_Adelaide' contains 'BAS'.
# Checking layer: BAS_2012_Castle
# Layer 'BAS_2012_Castle' contains 'BAS'.
# Checking layer: BAS_2013_ISTAR
# Layer 'BAS_2013_ISTAR' contains 'BAS'.
# Checking layer: BAS_2018_Thwaites
# Layer 'BAS_2018_Thwaites' contains 'BAS'.
# Checking layer: BAS_2019_Thwaites
# Layer 'BAS_2019_Thwaites' contains 'BAS'.
# Checking layer: AGAP
# Layer 'AGAP' contains 'BAS'.
# Checking layer: BBAS
# Layer 'BBAS' contains 'BAS'.
# Checking layer: FISS2015
# Layer 'FISS2015' contains 'BAS'.
# Checking layer: FISS2016
# Layer 'FISS2016' contains 'BAS'.
# Checking layer: GRADES_IMAGE
# Layer 'GRADES_IMAGE' contains 'BAS'.
# Checking layer: ICEGRAV
# Layer 'ICEGRAV' contains 'BAS'.
# Checking layer: IMAFI
# Layer 'IMAFI' contains 'BAS'.
# Checking layer: ITGC_2019
# Layer 'ITGC_2019' contains 'BAS'.
# Checking layer: POLARGAP
# Layer 'POLARGAP' contains 'BAS'.
# Checking layer: WISE_ISODYN
# Layer 'WISE_ISODYN' contains 'BAS'.
# Checking layer: BAS_1969_1970
# Layer 'BAS_1969_1970' contains 'BAS'.
# Checking layer: BAS_1971_1972
# Layer 'BAS_1971_1972' contains 'BAS'.
# Checking layer: BAS_1974_1975
# Layer 'BAS_1974_1975' contains 'BAS'.
# Checking layer: BAS_1980_1981
# Layer 'BAS_1980_1981' contains 'BAS'.
# Checking layer: BAS_1982_1983
# Layer 'BAS_1982_1983' contains 'BAS'.
# Checking layer: BAS_1983_1984
# Layer 'BAS_1983_1984' contains 'BAS'.
# Checking layer: BAS_1984_1985
# Layer 'BAS_1984_1985' contains 'BAS'.
# Checking layer: BAS_1985_1986
# Layer 'BAS_1985_1986' contains 'BAS'.
# Checking layer: BAS_1987_1988
# Layer 'BAS_1987_1988' contains 'BAS'.
# Checking layer: campaigns
# Layer 'campaigns' contains 'BAS'.
# Saved map for BAS to ./data3/Antarctica_coverage_BAS.png
#
# Processing institution: BEDMAP1
# Checking layer: BEDMAP1_BEDMAP1
# Layer 'BEDMAP1_BEDMAP1' contains 'BEDMAP1'.
# Saved map for BEDMAP1 to ./data3/Antarctica_coverage_BEDMAP1.png
#
# Processing institution: BGR
# Checking layer: BGR_1999_GANOVEX-VIII-Matusevich
# Layer 'BGR_1999_GANOVEX-VIII-Matusevich' contains 'BGR'.
# Checking layer: BGR_1999_GANOVEX-VIII-Mertz
# Layer 'BGR_1999_GANOVEX-VIII-Mertz' contains 'BGR'.
# Checking layer: BGR_2002_PCMEGA
# Layer 'BGR_2002_PCMEGA' contains 'BGR'.
# Saved map for BGR to ./data3/Antarctica_coverage_BGR.png
#
# Processing institution: CECS
# Checking layer: CECS_2006_Subglacial-Lake-CECs
# Layer 'CECS_2006_Subglacial-Lake-CECs' contains 'CECS'.
# Saved map for CECS to ./data3/Antarctica_coverage_CECS.png
#
# Processing institution: INGV
# Checking layer: INGV_1997_ITASE
# Layer 'INGV_1997_ITASE' contains 'INGV'.
# Checking layer: INGV_1997_Talos-Dome
# Layer 'INGV_1997_Talos-Dome' contains 'INGV'.
# Checking layer: INGV_1999_Talos-Dome
# Layer 'INGV_1999_Talos-Dome' contains 'INGV'.
# Checking layer: INGV_2001_Talos-Dome
# Layer 'INGV_2001_Talos-Dome' contains 'INGV'.
# Checking layer: INGV_2003_Talos-Dome
# Layer 'INGV_2003_Talos-Dome' contains 'INGV'.
# Saved map for INGV to ./data3/Antarctica_coverage_INGV.png
#
# Processing institution: KOPRI
# Checking layer: KOPRI_2017_KRT1
# Layer 'KOPRI_2017_KRT1' contains 'KOPRI'.
# Checking layer: KOPRI_2018_KRT2
# Layer 'KOPRI_2018_KRT2' contains 'KOPRI'.
# Checking layer: KRT1
# Layer 'KRT1' contains 'KOPRI'.
# Saved map for KOPRI to ./data3/Antarctica_coverage_KOPRI.png
#
# Processing institution: LDEO
# Checking layer: LDEO_2007_Recovery-Lakes
# Layer 'LDEO_2007_Recovery-Lakes' contains 'LDEO'.
# Checking layer: LDEO_2015_ROSETTA
# Layer 'LDEO_2015_ROSETTA' contains 'LDEO'.
# Checking layer: AGAP_GAMBIT
# Layer 'AGAP_GAMBIT' contains 'LDEO'.
# Saved map for LDEO to ./data3/Antarctica_coverage_LDEO.png
#
# Processing institution: NASA
# Checking layer: NASA_2002_ICEBRIDGE
# Layer 'NASA_2002_ICEBRIDGE' contains 'NASA'.
# Saved map for NASA to ./data3/Antarctica_coverage_NASA.png
#
# Processing institution: NIPR
# Checking layer: NIPR_1992_JARE33
# Layer 'NIPR_1992_JARE33' contains 'NIPR'.
# Checking layer: NIPR_1996_JARE37
# Layer 'NIPR_1996_JARE37' contains 'NIPR'.
# Checking layer: NIPR_1999_JARE40
# Layer 'NIPR_1999_JARE40' contains 'NIPR'.
# Checking layer: NIPR_2007_JARE49
# Layer 'NIPR_2007_JARE49' contains 'NIPR'.
# Checking layer: NIPR_2007_JASE
# Layer 'NIPR_2007_JASE' contains 'NIPR'.
# Checking layer: NIPR_2012_JARE54
# Layer 'NIPR_2012_JARE54' contains 'NIPR'.
# Checking layer: NIPR_2017_JARE59
# Layer 'NIPR_2017_JARE59' contains 'NIPR'.
# Checking layer: NIPR_2018_JARE60
# Layer 'NIPR_2018_JARE60' contains 'NIPR'.
# Saved map for NIPR to ./data3/Antarctica_coverage_NIPR.png
#
# Processing institution: NPI
# Checking layer: NPI_2008_BELISSIMA
# Layer 'NPI_2008_BELISSIMA' contains 'NPI'.
# Checking layer: NPI_2010_SRM
# Layer 'NPI_2010_SRM' contains 'NPI'.
# Checking layer: NPI_2012_ICERISES
# Layer 'NPI_2012_ICERISES' contains 'NPI'.
# Checking layer: NPI_2015_POLARGAP
# Layer 'NPI_2015_POLARGAP' contains 'NPI'.
# Checking layer: NPI_2016_MADICE
# Layer 'NPI_2016_MADICE' contains 'NPI'.
# Saved map for NPI to ./data3/Antarctica_coverage_NPI.png
#
# Processing institution: PRIC
# Checking layer: PRIC_2004_CHINARE-21
# Layer 'PRIC_2004_CHINARE-21' contains 'PRIC'.
# Checking layer: PRIC_2007_CHINARE-24
# Layer 'PRIC_2007_CHINARE-24' contains 'PRIC'.
# Checking layer: PRIC_2015_CHA1
# Layer 'PRIC_2015_CHA1' contains 'PRIC'.
# Checking layer: PRIC_2016_CHA2
# Layer 'PRIC_2016_CHA2' contains 'PRIC'.
# Checking layer: PRIC_2017_CHA3
# Layer 'PRIC_2017_CHA3' contains 'PRIC'.
# Checking layer: PRIC_2018_CHA4
# Layer 'PRIC_2018_CHA4' contains 'PRIC'.
# Saved map for PRIC to ./data3/Antarctica_coverage_PRIC.png
#
# Processing institution: RNRF
# Checking layer: RNRF_1971_Lambert-Amery
# Layer 'RNRF_1971_Lambert-Amery' contains 'RNRF'.
# Checking layer: RNRF_1975_Filchner-Ronne
# Layer 'RNRF_1975_Filchner-Ronne' contains 'RNRF'.
# Checking layer: RNRF_1975_Lazarev
# Layer 'RNRF_1975_Lazarev' contains 'RNRF'.
# Checking layer: RNRF_2003_48RAEap5
# Layer 'RNRF_2003_48RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2003_AMSap5
# Layer 'RNRF_2003_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2004_49RAEap5
# Layer 'RNRF_2004_49RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2004_AMSap5
# Layer 'RNRF_2004_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2004_Mirny-Vostok
# Layer 'RNRF_2004_Mirny-Vostok' contains 'RNRF'.
# Checking layer: RNRF_2005_50RAEap5
# Layer 'RNRF_2005_50RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2005_AMSap5
# Layer 'RNRF_2005_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2006_51RAEap5
# Layer 'RNRF_2006_51RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2006_KV1-area
# Layer 'RNRF_2006_KV1-area' contains 'RNRF'.
# Checking layer: RNRF_2006_Komsom-Vostok
# Layer 'RNRF_2006_Komsom-Vostok' contains 'RNRF'.
# Checking layer: RNRF_2006_RAEap5
# Layer 'RNRF_2006_RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2007_52RAEap5
# Layer 'RNRF_2007_52RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2007_AMSap5
# Layer 'RNRF_2007_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2007_Mirny-Vostok
# Layer 'RNRF_2007_Mirny-Vostok' contains 'RNRF'.
# Checking layer: RNRF_2008_53RAEap5
# Layer 'RNRF_2008_53RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2008_AMSap5
# Layer 'RNRF_2008_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2008_Vostok-Subglacial-Lake
# Layer 'RNRF_2008_Vostok-Subglacial-Lake' contains 'RNRF'.
# Checking layer: RNRF_2009_RAEap5
# Layer 'RNRF_2009_RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2010_RAE
# Layer 'RNRF_2010_RAE' contains 'RNRF'.
# Checking layer: RNRF_2011_RAE
# Layer 'RNRF_2011_RAE' contains 'RNRF'.
# Checking layer: RNRF_2013_RAE
# Layer 'RNRF_2013_RAE' contains 'RNRF'.
# Checking layer: RNRF_2013_Vostok-Progress
# Layer 'RNRF_2013_Vostok-Progress' contains 'RNRF'.
# Checking layer: RNRF_2014_RAE
# Layer 'RNRF_2014_RAE' contains 'RNRF'.
# Checking layer: RNRF_2015_RAE
# Layer 'RNRF_2015_RAE' contains 'RNRF'.
# Checking layer: RNRF_2016_RAE
# Layer 'RNRF_2016_RAE' contains 'RNRF'.
# Checking layer: RNRF_2017_RAE
# Layer 'RNRF_2017_RAE' contains 'RNRF'.
# Checking layer: RNRF_2018_RAE
# Layer 'RNRF_2018_RAE' contains 'RNRF'.
# Checking layer: RNRF_2019_RAE
# Layer 'RNRF_2019_RAE' contains 'RNRF'.
# Saved map for RNRF to ./data3/Antarctica_coverage_RNRF.png
#
# Processing institution: STOLAF
# Checking layer: STOLAF_1994_Siple-Dome
# Layer 'STOLAF_1994_Siple-Dome' contains 'STOLAF'.
# Checking layer: STOLAF_2001_ITASE-Byrd-Ellsworth
# Layer 'STOLAF_2001_ITASE-Byrd-Ellsworth' contains 'STOLAF'.
# Checking layer: STOLAF_2001_ITASE-Ellsworth
# Layer 'STOLAF_2001_ITASE-Ellsworth' contains 'STOLAF'.
# Checking layer: STOLAF_2002_ITASE-Byrd-South-Pole
# Layer 'STOLAF_2002_ITASE-Byrd-South-Pole' contains 'STOLAF'.
# Checking layer: STOLAF_2002_ITASE-Hercules-Dome
# Layer 'STOLAF_2002_ITASE-Hercules-Dome' contains 'STOLAF'.
# Saved map for STOLAF to ./data3/Antarctica_coverage_STOLAF.png
#
# Processing institution: UCANTERBURY
# Checking layer: UCANTERBURY_2008_Darwin-Hatherton
# Layer 'UCANTERBURY_2008_Darwin-Hatherton' contains 'UCANTERBURY'.
# Saved map for UCANTERBURY to ./data3/Antarctica_coverage_UCANTERBURY.png
#
# Processing institution: ULB
# Checking layer: ULB_2012_BEWISE
# Layer 'ULB_2012_BEWISE' contains 'ULB'.
# Checking layer: ULB_2012_ICECON
# Layer 'ULB_2012_ICECON' contains 'ULB'.
# Saved map for ULB to ./data3/Antarctica_coverage_ULB.png
#
# Processing institution: UTIG
# Checking layer: UTIG_1991_CASERTZ
# Layer 'UTIG_1991_CASERTZ' contains 'UTIG'.
# Checking layer: UTIG_1998_West-Marie-Byrd-Land
# Layer 'UTIG_1998_West-Marie-Byrd-Land' contains 'UTIG'.
# Checking layer: UTIG_1999_SOAR-LVS-WLK
# Layer 'UTIG_1999_SOAR-LVS-WLK' contains 'UTIG'.
# Checking layer: UTIG_2000_Robb-Glacier
# Layer 'UTIG_2000_Robb-Glacier' contains 'UTIG'.
# Checking layer: UTIG_2008_ICECAP
# Layer 'UTIG_2008_ICECAP' contains 'UTIG'.
# Checking layer: UTIG_2009_Darwin-Hatherton
# Layer 'UTIG_2009_Darwin-Hatherton' contains 'UTIG'.
# Checking layer: UTIG_2010_ICECAP
# Layer 'UTIG_2010_ICECAP' contains 'UTIG'.
# Checking layer: UTIG_2013_GIMBLE
# Layer 'UTIG_2013_GIMBLE' contains 'UTIG'.
# Checking layer: AGASEA
# Layer 'AGASEA' contains 'UTIG'.
# Checking layer: EAGLE
# Layer 'EAGLE' contains 'UTIG'.
# Checking layer: ICECAP
# Layer 'ICECAP' contains 'UTIG'.
# Checking layer: OIA
# Layer 'OIA' contains 'UTIG'.
# Saved map for UTIG to ./data3/Antarctica_coverage_UTIG.png
#
# Processing institution: UWASHINGTON
# Checking layer: UWASHINGTON_2018_South-Pole-Lake
# Layer 'UWASHINGTON_2018_South-Pole-Lake' contains 'UWASHINGTON'.
# Saved map for UWASHINGTON to ./data3/Antarctica_coverage_UWASHINGTON.png
#
# Processing institution: CRESIS
# Checking layer: 2002_Antarctica_P3chile
# Layer '2002_Antarctica_P3chile' contains 'CRESIS'.
# Checking layer: 2004_Antarctica_P3chile
# Layer '2004_Antarctica_P3chile' contains 'CRESIS'.
# Checking layer: 2005_Antarctica_GPRWAIS
# Layer '2005_Antarctica_GPRWAIS' contains 'CRESIS'.
# Checking layer: 2009_Antarctica_DC8
# Layer '2009_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2009_Antarctica_TO
# Layer '2009_Antarctica_TO' contains 'CRESIS'.
# Checking layer: 2009_Antarctica_TO_Gambit
# Layer '2009_Antarctica_TO_Gambit' contains 'CRESIS'.
# Checking layer: 2010_Antarctica_DC8
# Layer '2010_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2011_Antarctica_DC8
# Layer '2011_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2011_Antarctica_TO
# Layer '2011_Antarctica_TO' contains 'CRESIS'.
# Checking layer: 2012_Antarctica_DC8
# Layer '2012_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2013_Antarctica_Basler
# Layer '2013_Antarctica_Basler' contains 'CRESIS'.
# Checking layer: 2013_Antarctica_P3
# Layer '2013_Antarctica_P3' contains 'CRESIS'.
# Checking layer: 2014_Antarctica_DC8
# Layer '2014_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2016_Antarctica_DC8
# Layer '2016_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2017_Antarctica_Basler
# Layer '2017_Antarctica_Basler' contains 'CRESIS'.
# Checking layer: 2017_Antarctica_P3
# Layer '2017_Antarctica_P3' contains 'CRESIS'.
# Checking layer: 2018_Antarctica_DC8
# Layer '2018_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2018_Antarctica_Ground
# Layer '2018_Antarctica_Ground' contains 'CRESIS'.
# Checking layer: 2019_Antarctica_GV
# Layer '2019_Antarctica_GV' contains 'CRESIS'.
# Saved map for CRESIS to ./data3/Antarctica_coverage_CRESIS.png
#
# Processing institution: STANFORD
# Checking layer: STANFORD_SPRI_NSF_TUD
# Layer 'STANFORD_SPRI_NSF_TUD' contains 'STANFORD'.
# Saved map for STANFORD to ./data3/Antarctica_coverage_STANFORD.png
# Saved map for Overview to ./data3/Antarctica_coverage_overview.png
# All maps have been created and saved to the data3 folder.
