# %%
import geopandas as gpd
import pandas as pd
import os
import fiona
from matplotlib_scalebar.scalebar import ScaleBar
import matplotlib.pyplot as plt

# Define the paths
input_file_path = "./antarctic_index.gpkg"
map_path = "/Users/nathanbekele/Downloads/Quantarctica3/Miscellaneous/SimpleBasemap/ADD_DerivedLowresBasemap.shp"
output_folder = "./data3"
statistics_folder = "./data_statistics"

# Ensure the output folders exist
os.makedirs(output_folder, exist_ok=True)
os.makedirs(statistics_folder, exist_ok=True)

# Read the GeoPackage file into a GeoDataFrame
fp = gpd.read_file(input_file_path)

# Read the map shapefile
mp = gpd.read_file(map_path)

# Check if the 'Category' column exists
if 'Category' in mp.columns:
    # Define the colors for the categories
    category_colors = {
        'Ocean': '#a3bdd1',
        'Ice shelf': '#cfe1eb',
        'Land': '#f0f0f0',
        'Sub-antarctic_G': 'lightgreen',
        'Sub-antarctic_L': 'lightblue',
        'Ice tongue': 'lightgrey',
        'Rumple': 'yellow',
    }

    # Create a color column based on the 'Category' column
    mp['color'] = mp['Category'].map(category_colors).fillna('grey')  # Default to grey for undefined categories

    # Function to plot data on the colored basemap
    def plot_data_on_basemap(basemap, gdf, institution, filename):
        fig, ax = plt.subplots(figsize=(10, 10))

        # Set background color to light blue
        fig.patch.set_facecolor('white')
        ax.set_facecolor('white')

        # Plot basemap with custom colors
        basemap.plot(ax=ax, color=basemap['color'], edgecolor='black')

        # Define colors and labels based on availability
        availability_colors = {'u': '#fb9a99', 's': '#1f78bc', 'r': 'darkgrey'}
        availability_labels = {'u': 'Unavailable', 's': 'Available', 'r': 'Other'}

        # Plot the data for the institution
        if not gdf.empty:
            for availability in gdf['availability'].unique():
                print(f"Processing availability '{availability}' for institution '{institution}'")
                subset = gdf[gdf['availability'] == availability]
                print(f"Subset for availability '{availability}': {subset}")
                color = availability_colors.get(availability, 'darkgrey')
                label = availability_labels.get(availability, 'Other')
                subset.plot(ax=ax, color=color, markersize=.55, linewidth=0.25, label=label)

        # Set limits to zoom in on Antarctica
        ax.set_xlim(-3e6, 3e6)
        ax.set_ylim(-3e6, 3e6)

        # Add scale bar
        scalebar = ScaleBar(1, location='lower right')
        ax.add_artist(scalebar)

        plt.title(f'Antarctica Basemap with {institution} Data Overlay')

        # Handle legend
        handles, labels = ax.get_legend_handles_labels()
        unique_labels = dict(zip(labels, handles))
        ax.legend(unique_labels.values(), unique_labels.keys())

        # Save the plot to the data folder
        output_path = os.path.join(output_folder, filename)
        plt.savefig(output_path)
        plt.close(fig)
        print(f"Saved map for {institution} to {output_path}")

    try:
        layers = fiona.listlayers(input_file_path)
        if not layers:
            raise ValueError("No layers found in the GeoPackage.")
        print("Layers in the GeoPackage:")
        print(layers)
    except Exception as e:
        print(f"Error listing layers in the GeoPackage: {e}")
        layers = []

    if not layers:
        print("No layers found or error in listing layers. Exiting.")
    else:
        # Create a dictionary to map institutions to layers
        institution_layers = {}

        # Populate the dictionary
        for layer in layers:
            try:
                gdf = gpd.read_file(input_file_path, layer=layer)  # Read the full layer
                if 'institution' in gdf.columns:
                    institutions = gdf['institution'].unique()
                    for institution in institutions:
                        if institution not in institution_layers:
                            institution_layers[institution] = []
                        institution_layers[institution].append(layer)
            except Exception as e:
                print(f"Error reading layer {layer}: {e}")

        print("Institution layers mapping:")
        print(institution_layers)

        # Create an overview GeoDataFrame
        overview_gdf = gpd.GeoDataFrame()

        # Iterate through each institution and create maps
        for institution, layers in institution_layers.items():
            institution_data = []

            print(f"\nProcessing institution: {institution}")

            for layer in layers:
                print(f"Checking layer: {layer}")
                try:
                    gdf = gpd.read_file(input_file_path, layer=layer)  # Read the full layer

                    if 'institution' in gdf.columns and institution in gdf['institution'].unique():
                        print(f"Layer '{layer}' contains '{institution}'.")
                        institution_data.append(gdf[gdf['institution'] == institution])
                    else:
                        print(f"Layer '{layer}' does not contain '{institution}' or does not have 'institution' column.")
                except Exception as e:
                    print(f"Error processing layer {layer}: {e}")

            # Combine all dataframes for the institution
            if institution_data:
                institution_gdf = gpd.GeoDataFrame(pd.concat(institution_data, ignore_index=True))
            else:
                institution_gdf = gpd.GeoDataFrame()

            # Ensure the CRS matches between the basemap and the GeoDataFrame
            if not institution_gdf.empty:
                institution_gdf = institution_gdf.to_crs(mp.crs)

            # Add to the overview GeoDataFrame
            if not institution_gdf.empty:
                overview_gdf = pd.concat([overview_gdf, institution_gdf])

            # Plot and save the aggregated data for the institution
            plot_data_on_basemap(mp, institution_gdf, institution, f'Antarctica_coverage_{institution}.png')

        # Ensure the CRS matches between the basemap and the overview GeoDataFrame
        if not overview_gdf.empty:
            overview_gdf = gpd.GeoDataFrame(overview_gdf).to_crs(mp.crs)

        # Plot and save the overview map
        plot_data_on_basemap(mp, overview_gdf, "Overview", 'Antarctica_coverage_overview.png')

        print("All maps have been created and saved to the data3 folder.")

else:
    print("The 'Category' column does not exist in the GeoDataFrame.")
# Out:
# Layers in the GeoPackage:
# ['AWI_1994_DML1', 'AWI_1995_DML2', 'AWI_1996_DML3', 'AWI_1997_DML4', 'AWI_1998_DML5', 'AWI_2000_DML6', 'AWI_2001_DML7', 'AWI_2002_DML8', 'AWI_2003_DML9', 'AWI_2004_DML10', 'AWI_2005_ANTSYSO', 'AWI_2007_ANTR', 'AWI_2013_GEA-IV', 'AWI_2014_Recovery-Glacier', 'AWI_2015_GEA-DML', 'AWI_2016_OIR', 'AWI_2018_ANIRES', 'AWI_2018_DML-Coast', 'AWI_2018_JURAS', 'AWI_2019_JURAS', 'BAS_1994_Evans', 'BAS_1998_Dufek', 'BAS_2001_Bailey-Slessor', 'BAS_2001_MAMOG', 'BAS_2002_TORUS', 'BAS_2007_Lake-Ellsworth', 'BAS_2007_Rutford', 'BAS_2007_TIGRIS', 'BAS_2008_Lake-Ellsworth', 'BAS_2009_FERRIGNO', 'BAS_2010_PIG', 'BAS_2011_Adelaide', 'BAS_2012_Castle', 'BAS_2013_ISTAR', 'BAS_2018_Thwaites', 'BAS_2019_Thwaites', 'BEDMAP1_BEDMAP1', 'BGR_1999_GANOVEX-VIII-Matusevich', 'BGR_1999_GANOVEX-VIII-Mertz', 'BGR_2002_PCMEGA', 'CECS_2006_Subglacial-Lake-CECs', 'INGV_1997_ITASE', 'INGV_1997_Talos-Dome', 'INGV_1999_Talos-Dome', 'INGV_2001_Talos-Dome', 'INGV_2003_Talos-Dome', 'KOPRI_2017_KRT1', 'KOPRI_2018_KRT2', 'LDEO_2007_Recovery-Lakes', 'LDEO_2015_ROSETTA', 'NASA_2002_ICEBRIDGE', 'NIPR_1992_JARE33', 'NIPR_1996_JARE37', 'NIPR_1999_JARE40', 'NIPR_2007_JARE49', 'NIPR_2007_JASE', 'NIPR_2012_JARE54', 'NIPR_2017_JARE59', 'NIPR_2018_JARE60', 'NPI_2008_BELISSIMA', 'NPI_2010_SRM', 'NPI_2012_ICERISES', 'NPI_2015_POLARGAP', 'NPI_2016_MADICE', 'PRIC_2004_CHINARE-21', 'PRIC_2007_CHINARE-24', 'PRIC_2015_CHA1', 'PRIC_2016_CHA2', 'PRIC_2017_CHA3', 'PRIC_2018_CHA4', 'RNRF_1971_Lambert-Amery', 'RNRF_1975_Filchner-Ronne', 'RNRF_1975_Lazarev', 'RNRF_2003_48RAEap5', 'RNRF_2003_AMSap5', 'RNRF_2004_49RAEap5', 'RNRF_2004_AMSap5', 'RNRF_2004_Mirny-Vostok', 'RNRF_2005_50RAEap5', 'RNRF_2005_AMSap5', 'RNRF_2006_51RAEap5', 'RNRF_2006_KV1-area', 'RNRF_2006_Komsom-Vostok', 'RNRF_2006_RAEap5', 'RNRF_2007_52RAEap5', 'RNRF_2007_AMSap5', 'RNRF_2007_Mirny-Vostok', 'RNRF_2008_53RAEap5', 'RNRF_2008_AMSap5', 'RNRF_2008_Vostok-Subglacial-Lake', 'RNRF_2009_RAEap5', 'RNRF_2010_RAE', 'RNRF_2011_RAE', 'RNRF_2013_RAE', 'RNRF_2013_Vostok-Progress', 'RNRF_2014_RAE', 'RNRF_2015_RAE', 'RNRF_2016_RAE', 'RNRF_2017_RAE', 'RNRF_2018_RAE', 'RNRF_2019_RAE', 'STOLAF_1994_Siple-Dome', 'STOLAF_2001_ITASE-Byrd-Ellsworth', 'STOLAF_2001_ITASE-Ellsworth', 'STOLAF_2002_ITASE-Byrd-South-Pole', 'STOLAF_2002_ITASE-Hercules-Dome', 'UCANTERBURY_2008_Darwin-Hatherton', 'ULB_2012_BEWISE', 'ULB_2012_ICECON', 'UTIG_1991_CASERTZ', 'UTIG_1998_West-Marie-Byrd-Land', 'UTIG_1999_SOAR-LVS-WLK', 'UTIG_2000_Robb-Glacier', 'UTIG_2008_ICECAP', 'UTIG_2009_Darwin-Hatherton', 'UTIG_2010_ICECAP', 'UTIG_2013_GIMBLE', 'UWASHINGTON_2018_South-Pole-Lake', 'AGAP', 'BBAS', 'FISS2015', 'FISS2016', 'GRADES_IMAGE', 'ICEGRAV', 'IMAFI', 'ITGC_2019', 'POLARGAP', 'WISE_ISODYN', '2002_Antarctica_P3chile', '2004_Antarctica_P3chile', '2005_Antarctica_GPRWAIS', '2009_Antarctica_DC8', '2009_Antarctica_TO', '2009_Antarctica_TO_Gambit', '2010_Antarctica_DC8', '2011_Antarctica_DC8', '2011_Antarctica_TO', '2012_Antarctica_DC8', '2013_Antarctica_Basler', '2013_Antarctica_P3', '2014_Antarctica_DC8', '2016_Antarctica_DC8', '2017_Antarctica_Basler', '2017_Antarctica_P3', '2018_Antarctica_DC8', '2018_Antarctica_Ground', '2019_Antarctica_GV', 'KRT1', 'AGAP_GAMBIT', 'AGASEA', 'DVD', 'EAGLE', 'ICECAP', 'LIV', 'OIA', 'STI', 'TAM', 'WAG', 'BAS_1969_1970', 'BAS_1971_1972', 'BAS_1974_1975', 'BAS_1980_1981', 'BAS_1982_1983', 'BAS_1983_1984', 'BAS_1984_1985', 'BAS_1985_1986', 'BAS_1987_1988', 'STANFORD_SPRI_NSF_TUD', 'institutions', 'data_formats', 'download_methods', 'campaigns', 'granules']
# Institution layers mapping:
# {'AWI': ['AWI_1994_DML1', 'AWI_1995_DML2', 'AWI_1996_DML3', 'AWI_1997_DML4', 'AWI_1998_DML5', 'AWI_2000_DML6', 'AWI_2001_DML7', 'AWI_2002_DML8', 'AWI_2003_DML9', 'AWI_2004_DML10', 'AWI_2005_ANTSYSO', 'AWI_2007_ANTR', 'AWI_2013_GEA-IV', 'AWI_2014_Recovery-Glacier', 'AWI_2015_GEA-DML', 'AWI_2016_OIR', 'AWI_2018_ANIRES', 'AWI_2018_DML-Coast', 'AWI_2018_JURAS', 'AWI_2019_JURAS'], 'BAS': ['BAS_1994_Evans', 'BAS_1998_Dufek', 'BAS_2001_Bailey-Slessor', 'BAS_2001_MAMOG', 'BAS_2002_TORUS', 'BAS_2007_Lake-Ellsworth', 'BAS_2007_Rutford', 'BAS_2007_TIGRIS', 'BAS_2008_Lake-Ellsworth', 'BAS_2009_FERRIGNO', 'BAS_2010_PIG', 'BAS_2011_Adelaide', 'BAS_2012_Castle', 'BAS_2013_ISTAR', 'BAS_2018_Thwaites', 'BAS_2019_Thwaites', 'AGAP', 'BBAS', 'FISS2015', 'FISS2016', 'GRADES_IMAGE', 'ICEGRAV', 'IMAFI', 'ITGC_2019', 'POLARGAP', 'WISE_ISODYN', 'BAS_1969_1970', 'BAS_1971_1972', 'BAS_1974_1975', 'BAS_1980_1981', 'BAS_1982_1983', 'BAS_1983_1984', 'BAS_1984_1985', 'BAS_1985_1986', 'BAS_1987_1988', 'campaigns'], 'BEDMAP1': ['BEDMAP1_BEDMAP1'], 'BGR': ['BGR_1999_GANOVEX-VIII-Matusevich', 'BGR_1999_GANOVEX-VIII-Mertz', 'BGR_2002_PCMEGA'], 'CECS': ['CECS_2006_Subglacial-Lake-CECs'], 'INGV': ['INGV_1997_ITASE', 'INGV_1997_Talos-Dome', 'INGV_1999_Talos-Dome', 'INGV_2001_Talos-Dome', 'INGV_2003_Talos-Dome'], 'KOPRI': ['KOPRI_2017_KRT1', 'KOPRI_2018_KRT2', 'KRT1'], 'LDEO': ['LDEO_2007_Recovery-Lakes', 'LDEO_2015_ROSETTA', 'AGAP_GAMBIT'], 'NASA': ['NASA_2002_ICEBRIDGE'], 'NIPR': ['NIPR_1992_JARE33', 'NIPR_1996_JARE37', 'NIPR_1999_JARE40', 'NIPR_2007_JARE49', 'NIPR_2007_JASE', 'NIPR_2012_JARE54', 'NIPR_2017_JARE59', 'NIPR_2018_JARE60'], 'NPI': ['NPI_2008_BELISSIMA', 'NPI_2010_SRM', 'NPI_2012_ICERISES', 'NPI_2015_POLARGAP', 'NPI_2016_MADICE'], 'PRIC': ['PRIC_2004_CHINARE-21', 'PRIC_2007_CHINARE-24', 'PRIC_2015_CHA1', 'PRIC_2016_CHA2', 'PRIC_2017_CHA3', 'PRIC_2018_CHA4'], 'RNRF': ['RNRF_1971_Lambert-Amery', 'RNRF_1975_Filchner-Ronne', 'RNRF_1975_Lazarev', 'RNRF_2003_48RAEap5', 'RNRF_2003_AMSap5', 'RNRF_2004_49RAEap5', 'RNRF_2004_AMSap5', 'RNRF_2004_Mirny-Vostok', 'RNRF_2005_50RAEap5', 'RNRF_2005_AMSap5', 'RNRF_2006_51RAEap5', 'RNRF_2006_KV1-area', 'RNRF_2006_Komsom-Vostok', 'RNRF_2006_RAEap5', 'RNRF_2007_52RAEap5', 'RNRF_2007_AMSap5', 'RNRF_2007_Mirny-Vostok', 'RNRF_2008_53RAEap5', 'RNRF_2008_AMSap5', 'RNRF_2008_Vostok-Subglacial-Lake', 'RNRF_2009_RAEap5', 'RNRF_2010_RAE', 'RNRF_2011_RAE', 'RNRF_2013_RAE', 'RNRF_2013_Vostok-Progress', 'RNRF_2014_RAE', 'RNRF_2015_RAE', 'RNRF_2016_RAE', 'RNRF_2017_RAE', 'RNRF_2018_RAE', 'RNRF_2019_RAE'], 'STOLAF': ['STOLAF_1994_Siple-Dome', 'STOLAF_2001_ITASE-Byrd-Ellsworth', 'STOLAF_2001_ITASE-Ellsworth', 'STOLAF_2002_ITASE-Byrd-South-Pole', 'STOLAF_2002_ITASE-Hercules-Dome'], 'UCANTERBURY': ['UCANTERBURY_2008_Darwin-Hatherton'], 'ULB': ['ULB_2012_BEWISE', 'ULB_2012_ICECON'], 'UTIG': ['UTIG_1991_CASERTZ', 'UTIG_1998_West-Marie-Byrd-Land', 'UTIG_1999_SOAR-LVS-WLK', 'UTIG_2000_Robb-Glacier', 'UTIG_2008_ICECAP', 'UTIG_2009_Darwin-Hatherton', 'UTIG_2010_ICECAP', 'UTIG_2013_GIMBLE', 'AGASEA', 'EAGLE', 'ICECAP', 'OIA'], 'UWASHINGTON': ['UWASHINGTON_2018_South-Pole-Lake'], 'CRESIS': ['2002_Antarctica_P3chile', '2004_Antarctica_P3chile', '2005_Antarctica_GPRWAIS', '2009_Antarctica_DC8', '2009_Antarctica_TO', '2009_Antarctica_TO_Gambit', '2010_Antarctica_DC8', '2011_Antarctica_DC8', '2011_Antarctica_TO', '2012_Antarctica_DC8', '2013_Antarctica_Basler', '2013_Antarctica_P3', '2014_Antarctica_DC8', '2016_Antarctica_DC8', '2017_Antarctica_Basler', '2017_Antarctica_P3', '2018_Antarctica_DC8', '2018_Antarctica_Ground', '2019_Antarctica_GV'], 'STANFORD': ['STANFORD_SPRI_NSF_TUD']}
#
# Processing institution: AWI
# Checking layer: AWI_1994_DML1
# Layer 'AWI_1994_DML1' contains 'AWI'.
# Checking layer: AWI_1995_DML2
# Layer 'AWI_1995_DML2' contains 'AWI'.
# Checking layer: AWI_1996_DML3
# Layer 'AWI_1996_DML3' contains 'AWI'.
# Checking layer: AWI_1997_DML4
# Layer 'AWI_1997_DML4' contains 'AWI'.
# Checking layer: AWI_1998_DML5
# Layer 'AWI_1998_DML5' contains 'AWI'.
# Checking layer: AWI_2000_DML6
# Layer 'AWI_2000_DML6' contains 'AWI'.
# Checking layer: AWI_2001_DML7
# Layer 'AWI_2001_DML7' contains 'AWI'.
# Checking layer: AWI_2002_DML8
# Layer 'AWI_2002_DML8' contains 'AWI'.
# Checking layer: AWI_2003_DML9
# Layer 'AWI_2003_DML9' contains 'AWI'.
# Checking layer: AWI_2004_DML10
# Layer 'AWI_2004_DML10' contains 'AWI'.
# Checking layer: AWI_2005_ANTSYSO
# Layer 'AWI_2005_ANTSYSO' contains 'AWI'.
# Checking layer: AWI_2007_ANTR
# Layer 'AWI_2007_ANTR' contains 'AWI'.
# Checking layer: AWI_2013_GEA-IV
# Layer 'AWI_2013_GEA-IV' contains 'AWI'.
# Checking layer: AWI_2014_Recovery-Glacier
# Layer 'AWI_2014_Recovery-Glacier' contains 'AWI'.
# Checking layer: AWI_2015_GEA-DML
# Layer 'AWI_2015_GEA-DML' contains 'AWI'.
# Checking layer: AWI_2016_OIR
# Layer 'AWI_2016_OIR' contains 'AWI'.
# Checking layer: AWI_2018_ANIRES
# Layer 'AWI_2018_ANIRES' contains 'AWI'.
# Checking layer: AWI_2018_DML-Coast
# Layer 'AWI_2018_DML-Coast' contains 'AWI'.
# Checking layer: AWI_2018_JURAS
# Layer 'AWI_2018_JURAS' contains 'AWI'.
# Checking layer: AWI_2019_JURAS
# Layer 'AWI_2019_JURAS' contains 'AWI'.
# Processing availability 'u' for institution 'AWI'
# Subset for availability 'u':                          name   uri institution     region granule segment  \
# 0               AWI_1994_DML1  None         AWI  antarctic    None    None
# 1               AWI_1995_DML2  None         AWI  antarctic    None    None
# 2               AWI_1996_DML3  None         AWI  antarctic    None    None
# 3               AWI_1997_DML4  None         AWI  antarctic    None    None
# 4               AWI_1998_DML5  None         AWI  antarctic    None    None
# 5               AWI_2000_DML6  None         AWI  antarctic    None    None
# 6               AWI_2001_DML7  None         AWI  antarctic    None    None
# 7               AWI_2002_DML8  None         AWI  antarctic    None    None
# 8               AWI_2003_DML9  None         AWI  antarctic    None    None
# 9              AWI_2004_DML10  None         AWI  antarctic    None    None
# 10           AWI_2005_ANTSYSO  None         AWI  antarctic    None    None
# 11              AWI_2007_ANTR  None         AWI  antarctic    None    None
# 12            AWI_2013_GEA-IV  None         AWI  antarctic    None    None
# 13  AWI_2014_Recovery-Glacier  None         AWI  antarctic    None    None
# 14           AWI_2015_GEA-DML  None         AWI  antarctic    None    None
# 15               AWI_2016_OIR  None         AWI  antarctic    None    None
# 16            AWI_2018_ANIRES  None         AWI  antarctic    None    None
# 17         AWI_2018_DML-Coast  None         AWI  antarctic    None    None
# 18             AWI_2018_JURAS  None         AWI  antarctic    None    None
# 19             AWI_2019_JURAS  None         AWI  antarctic    None    None
#
#                  campaign availability  \
# 0               1994_DML1            u
# 1               1995_DML2            u
# 2               1996_DML3            u
# 3               1997_DML4            u
# 4               1998_DML5            u
# 5               2000_DML6            u
# 6               2001_DML7            u
# 7               2002_DML8            u
# 8               2003_DML9            u
# 9              2004_DML10            u
# 10           2005_ANTSYSO            u
# 11              2007_ANTR            u
# 12            2013_GEA-IV            u
# 13  2014_Recovery-Glacier            u
# 14           2015_GEA-DML            u
# 15               2016_OIR            u
# 16            2018_ANIRES            u
# 17         2018_DML-Coast            u
# 18             2018_JURAS            u
# 19             2019_JURAS            u
#
#                                              geometry
# 0   MULTIPOINT (-285560.755 1557735.604, -285182.1...
# 1   MULTIPOINT (665624.521 1734554.058, 665844.122...
# 2   MULTIPOINT (-394877.402 2040211.868, -394728.1...
# 3   MULTIPOINT (24872.282 1660804.497, 25215.086 1...
# 4   MULTIPOINT (97225.138 1400217.359, 97362.585 1...
# 5   MULTIPOINT (-305289.909 2107879.400, -305405.0...
# 6   MULTIPOINT (-34391.972 2232954.483, -34171.155...
# 7   MULTIPOINT (-329848.783 2105024.199, -329673.3...
# 8   MULTIPOINT (429363.346 2071023.507, 429395.687...
# 9   MULTIPOINT (-127363.665 1588948.216, -127017.8...
# 10  MULTIPOINT (1399980.201 1720588.125, 1399865.8...
# 11  MULTIPOINT (494218.705 1988011.073, 494391.129...
# 12  MULTIPOINT (848027.715 1645129.489, 847967.940...
# 13  MULTIPOINT (-93684.112 1009577.535, -93921.115...
# 14  MULTIPOINT (-210003.662 2069207.643, -209700.1...
# 15  MULTIPOINT (640383.458 980273.065, 640509.756 ...
# 16  MULTIPOINT (-308463.712 2077020.741, -308510.3...
# 17  MULTIPOINT (-55534.491 2068964.923, -55729.405...
# 18  MULTIPOINT (56226.332 1777993.395, 56037.764 1...
# 19  MULTIPOINT (787438.230 1776562.158, 787466.526...
# Saved map for AWI to ./data3/Antarctica_coverage_AWI.png
#
# Processing institution: BAS
# Checking layer: BAS_1994_Evans
# Layer 'BAS_1994_Evans' contains 'BAS'.
# Checking layer: BAS_1998_Dufek
# Layer 'BAS_1998_Dufek' contains 'BAS'.
# Checking layer: BAS_2001_Bailey-Slessor
# Layer 'BAS_2001_Bailey-Slessor' contains 'BAS'.
# Checking layer: BAS_2001_MAMOG
# Layer 'BAS_2001_MAMOG' contains 'BAS'.
# Checking layer: BAS_2002_TORUS
# Layer 'BAS_2002_TORUS' contains 'BAS'.
# Checking layer: BAS_2007_Lake-Ellsworth
# Layer 'BAS_2007_Lake-Ellsworth' contains 'BAS'.
# Checking layer: BAS_2007_Rutford
# Layer 'BAS_2007_Rutford' contains 'BAS'.
# Checking layer: BAS_2007_TIGRIS
# Layer 'BAS_2007_TIGRIS' contains 'BAS'.
# Checking layer: BAS_2008_Lake-Ellsworth
# Layer 'BAS_2008_Lake-Ellsworth' contains 'BAS'.
# Checking layer: BAS_2009_FERRIGNO
# Layer 'BAS_2009_FERRIGNO' contains 'BAS'.
# Checking layer: BAS_2010_PIG
# Layer 'BAS_2010_PIG' contains 'BAS'.
# Checking layer: BAS_2011_Adelaide
# Layer 'BAS_2011_Adelaide' contains 'BAS'.
# Checking layer: BAS_2012_Castle
# Layer 'BAS_2012_Castle' contains 'BAS'.
# Checking layer: BAS_2013_ISTAR
# Layer 'BAS_2013_ISTAR' contains 'BAS'.
# Checking layer: BAS_2018_Thwaites
# Layer 'BAS_2018_Thwaites' contains 'BAS'.
# Checking layer: BAS_2019_Thwaites
# Layer 'BAS_2019_Thwaites' contains 'BAS'.
# Checking layer: AGAP
# Layer 'AGAP' contains 'BAS'.
# Checking layer: BBAS
# Layer 'BBAS' contains 'BAS'.
# Checking layer: FISS2015
# Layer 'FISS2015' contains 'BAS'.
# Checking layer: FISS2016
# Layer 'FISS2016' contains 'BAS'.
# Checking layer: GRADES_IMAGE
# Layer 'GRADES_IMAGE' contains 'BAS'.
# Checking layer: ICEGRAV
# Layer 'ICEGRAV' contains 'BAS'.
# Checking layer: IMAFI
# Layer 'IMAFI' contains 'BAS'.
# Checking layer: ITGC_2019
# Layer 'ITGC_2019' contains 'BAS'.
# Checking layer: POLARGAP
# Layer 'POLARGAP' contains 'BAS'.
# Checking layer: WISE_ISODYN
# Layer 'WISE_ISODYN' contains 'BAS'.
# Checking layer: BAS_1969_1970
# Layer 'BAS_1969_1970' contains 'BAS'.
# Checking layer: BAS_1971_1972
# Layer 'BAS_1971_1972' contains 'BAS'.
# Checking layer: BAS_1974_1975
# Layer 'BAS_1974_1975' contains 'BAS'.
# Checking layer: BAS_1980_1981
# Layer 'BAS_1980_1981' contains 'BAS'.
# Checking layer: BAS_1982_1983
# Layer 'BAS_1982_1983' contains 'BAS'.
# Checking layer: BAS_1983_1984
# Layer 'BAS_1983_1984' contains 'BAS'.
# Checking layer: BAS_1984_1985
# Layer 'BAS_1984_1985' contains 'BAS'.
# Checking layer: BAS_1985_1986
# Layer 'BAS_1985_1986' contains 'BAS'.
# Checking layer: BAS_1987_1988
# Layer 'BAS_1987_1988' contains 'BAS'.
# Checking layer: campaigns
# Layer 'campaigns' contains 'BAS'.
# Processing availability 'u' for institution 'BAS'
# Subset for availability 'u':                              name   uri institution     region     granule  \
# 0                  BAS_1994_Evans  None         BAS  antarctic        None
# 1                  BAS_1998_Dufek  None         BAS  antarctic        None
# 2         BAS_2001_Bailey-Slessor  None         BAS  antarctic        None
# 3                  BAS_2001_MAMOG  None         BAS  antarctic        None
# 4                  BAS_2002_TORUS  None         BAS  antarctic        None
# ..                            ...   ...         ...        ...         ...
# 761  BAS_BAS_1987_1988_segment024  None         BAS  antarctic  segment024
# 762  BAS_BAS_1987_1988_segment025  None         BAS  antarctic  segment025
# 763  BAS_BAS_1987_1988_segment026  None         BAS  antarctic  segment026
# 764  BAS_BAS_1987_1988_segment027  None         BAS  antarctic  segment027
# 765  BAS_BAS_1987_1988_segment028  None         BAS  antarctic  segment028
#
#         segment             campaign availability  \
# 0          None           1994_Evans            u
# 1          None           1998_Dufek            u
# 2          None  2001_Bailey-Slessor            u
# 3          None           2001_MAMOG            u
# 4          None           2002_TORUS            u
# ..          ...                  ...          ...
# 761  segment024        BAS_1987_1988            u
# 762  segment025        BAS_1987_1988            u
# 763  segment026        BAS_1987_1988            u
# 764  segment027        BAS_1987_1988            u
# 765  segment028        BAS_1987_1988            u
#
#                                               geometry data_citation  \
# 0    MULTIPOINT (-1423263.100 347943.815, -1423446....           NaN
# 1    MULTIPOINT (-592843.951 423142.571, -592928.34...           NaN
# 2    MULTIPOINT (-164690.528 1186504.732, -164836.3...           NaN
# 3    MULTIPOINT (-78620.159 1985461.818, -74199.191...           NaN
# 4    MULTIPOINT (-1509368.573 152122.469, -1509199....           NaN
# ..                                                 ...           ...
# 761  LINESTRING (-1899991.361 756930.420, -1899405....           NaN
# 762  LINESTRING (-1766875.373 739641.481, -1765010....           NaN
# 763  LINESTRING (-1902182.955 761978.658, -1901962....           NaN
# 764  LINESTRING (-1899750.554 757027.050, -1899234....           NaN
# 765  LINESTRING (-2291446.531 912114.017, -2291164....           NaN
#
#     science_citation
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 761              NaN
# 762              NaN
# 763              NaN
# 764              NaN
# 765              NaN
#
# [348 rows x 11 columns]
# Processing availability 's' for institution 'BAS'
# Subset for availability 's':                                 name   uri institution     region  \
# 16                 BAS_AGAP_AGAP_A03  None         BAS  antarctic
# 17                 BAS_AGAP_AGAP_A04  None         BAS  antarctic
# 18                 BAS_AGAP_AGAP_A05  None         BAS  antarctic
# 19                BAS_AGAP_AGAP_A05A  None         BAS  antarctic
# 20                BAS_AGAP_AGAP_A06C  None         BAS  antarctic
# ..                               ...   ...         ...        ...
# 429  BAS_WISE_ISODYN_WISE_ISODYN_W64  None         BAS  antarctic
# 430  BAS_WISE_ISODYN_WISE_ISODYN_W65  None         BAS  antarctic
# 431  BAS_WISE_ISODYN_WISE_ISODYN_W66  None         BAS  antarctic
# 432  BAS_WISE_ISODYN_WISE_ISODYN_W67  None         BAS  antarctic
# 433  BAS_WISE_ISODYN_WISE_ISODYN_W68  None         BAS  antarctic
#
#              granule          segment     campaign availability  \
# 16          AGAP_A03         AGAP_A03         AGAP            s
# 17          AGAP_A04         AGAP_A04         AGAP            s
# 18          AGAP_A05         AGAP_A05         AGAP            s
# 19         AGAP_A05A        AGAP_A05A         AGAP            s
# 20         AGAP_A06C        AGAP_A06C         AGAP            s
# ..               ...              ...          ...          ...
# 429  WISE_ISODYN_W64  WISE_ISODYN_W64  WISE_ISODYN            s
# 430  WISE_ISODYN_W65  WISE_ISODYN_W65  WISE_ISODYN            s
# 431  WISE_ISODYN_W66  WISE_ISODYN_W66  WISE_ISODYN            s
# 432  WISE_ISODYN_W67  WISE_ISODYN_W67  WISE_ISODYN            s
# 433  WISE_ISODYN_W68  WISE_ISODYN_W68  WISE_ISODYN            s
#
#                                               geometry data_citation  \
# 16   LINESTRING (249729.016 -1305354.471, 249179.82...           NaN
# 17   LINESTRING (260421.894 -1197599.389, 260348.55...           NaN
# 18   LINESTRING (265616.817 -685957.302, 265653.872...           NaN
# 19   LINESTRING (127506.382 -258418.054, 127211.708...           NaN
# 20   LINESTRING (-44410.750 -17539.299, -44626.876 ...           NaN
# ..                                                 ...           ...
# 429  LINESTRING (1048611.773 -1709394.912, 1050496....           NaN
# 430  LINESTRING (1047865.561 -1711807.810, 1048772....           NaN
# 431  LINESTRING (1048153.233 -1724356.355, 1048621....           NaN
# 432  LINESTRING (1043342.349 -1707126.491, 1043263....           NaN
# 433  LINESTRING (462219.811 -1614284.746, 462552.58...           NaN
#
#     science_citation
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# ..               ...
# 429              NaN
# 430              NaN
# 431              NaN
# 432              NaN
# 433              NaN
#
# [418 rows x 11 columns]
# Processing availability 'nan' for institution 'BAS'
# Subset for availability 'nan': Empty GeoDataFrame
# Columns: [name, uri, institution, region, granule, segment, campaign, availability, geometry, data_citation, science_citation]
# Index: []
# /var/folders/vv/czt16t1x4_12h0xsl6rcd5_80000gn/T/ipykernel_14387/2103577489.py:63: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   subset.plot(ax=ax, color=color, markersize=.55, linewidth=0.25, label=label)
# Saved map for BAS to ./data3/Antarctica_coverage_BAS.png
#
# Processing institution: BEDMAP1
# Checking layer: BEDMAP1_BEDMAP1
# Layer 'BEDMAP1_BEDMAP1' contains 'BEDMAP1'.
# Processing availability 'u' for institution 'BEDMAP1'
# Subset for availability 'u':               name   uri institution     region granule segment campaign  \
# 0  BEDMAP1_BEDMAP1  None     BEDMAP1  antarctic    None    None  BEDMAP1
#
#   availability                                           geometry
# 0            u  MULTIPOINT (-393747.895 -1227610.318, -357254....
# Saved map for BEDMAP1 to ./data3/Antarctica_coverage_BEDMAP1.png
#
# Processing institution: BGR
# Checking layer: BGR_1999_GANOVEX-VIII-Matusevich
# Layer 'BGR_1999_GANOVEX-VIII-Matusevich' contains 'BGR'.
# Checking layer: BGR_1999_GANOVEX-VIII-Mertz
# Layer 'BGR_1999_GANOVEX-VIII-Mertz' contains 'BGR'.
# Checking layer: BGR_2002_PCMEGA
# Layer 'BGR_2002_PCMEGA' contains 'BGR'.
# Processing availability 'u' for institution 'BGR'
# Subset for availability 'u':                                name   uri institution     region granule  \
# 0  BGR_1999_GANOVEX-VIII-Matusevich  None         BGR  antarctic    None
# 1       BGR_1999_GANOVEX-VIII-Mertz  None         BGR  antarctic    None
# 2                   BGR_2002_PCMEGA  None         BGR  antarctic    None
#
#   segment                      campaign availability  \
# 0    None  1999_GANOVEX-VIII-Matusevich            u
# 1    None       1999_GANOVEX-VIII-Mertz            u
# 2    None                   2002_PCMEGA            u
#
#                                             geometry
# 0  MULTIPOINT (859317.111 -2087242.920, 858972.68...
# 1  MULTIPOINT (1319004.401 -2005565.224, 1319371....
# 2  MULTIPOINT (1706487.111 820905.142, 1706287.62...
# Saved map for BGR to ./data3/Antarctica_coverage_BGR.png
#
# Processing institution: CECS
# Checking layer: CECS_2006_Subglacial-Lake-CECs
# Layer 'CECS_2006_Subglacial-Lake-CECs' contains 'CECS'.
# Processing availability 'u' for institution 'CECS'
# Subset for availability 'u':                              name   uri institution     region granule  \
# 0  CECS_2006_Subglacial-Lake-CECs  None        CECS  antarctic    None
#
#   segment                   campaign availability  \
# 0    None  2006_Subglacial-Lake-CECs            u
#
#                                             geometry
# 0  MULTIPOINT (-1129205.410 37222.448, -1129390.2...
# Saved map for CECS to ./data3/Antarctica_coverage_CECS.png
#
# Processing institution: INGV
# Checking layer: INGV_1997_ITASE
# Layer 'INGV_1997_ITASE' contains 'INGV'.
# Checking layer: INGV_1997_Talos-Dome
# Layer 'INGV_1997_Talos-Dome' contains 'INGV'.
# Checking layer: INGV_1999_Talos-Dome
# Layer 'INGV_1999_Talos-Dome' contains 'INGV'.
# Checking layer: INGV_2001_Talos-Dome
# Layer 'INGV_2001_Talos-Dome' contains 'INGV'.
# Checking layer: INGV_2003_Talos-Dome
# Layer 'INGV_2003_Talos-Dome' contains 'INGV'.
# Processing availability 'u' for institution 'INGV'
# Subset for availability 'u':                    name   uri institution     region granule segment  \
# 0       INGV_1997_ITASE  None        INGV  antarctic    None    None
# 1  INGV_1997_Talos-Dome  None        INGV  antarctic    None    None
# 2  INGV_1999_Talos-Dome  None        INGV  antarctic    None    None
# 3  INGV_2001_Talos-Dome  None        INGV  antarctic    None    None
# 4  INGV_2003_Talos-Dome  None        INGV  antarctic    None    None
#
#           campaign availability  \
# 0       1997_ITASE            u
# 1  1997_Talos-Dome            u
# 2  1999_Talos-Dome            u
# 3  2001_Talos-Dome            u
# 4  2003_Talos-Dome            u
#
#                                             geometry
# 0  MULTIPOINT (684111.963 -1568472.426, 684385.50...
# 1  MULTIPOINT (711768.450 -1595640.249, 711858.76...
# 2  MULTIPOINT (1364169.618 -903496.377, 1364258.7...
# 3  MULTIPOINT (1443706.163 -995484.841, 1443516.0...
# 4  MULTIPOINT (493124.481 -1591867.946, 493307.33...
# Saved map for INGV to ./data3/Antarctica_coverage_INGV.png
#
# Processing institution: KOPRI
# Checking layer: KOPRI_2017_KRT1
# Layer 'KOPRI_2017_KRT1' contains 'KOPRI'.
# Checking layer: KOPRI_2018_KRT2
# Layer 'KOPRI_2018_KRT2' contains 'KOPRI'.
# Checking layer: KRT1
# Layer 'KRT1' contains 'KOPRI'.
# Processing availability 'u' for institution 'KOPRI'
# Subset for availability 'u':               name   uri institution     region granule segment   campaign  \
# 0  KOPRI_2017_KRT1  None       KOPRI  antarctic    None    None  2017_KRT1
# 1  KOPRI_2018_KRT2  None       KOPRI  antarctic    None    None  2018_KRT2
#
#   availability                                           geometry
# 0            u  MULTIPOINT (458340.233 -1643251.885, 458247.15...
# 1            u  MULTIPOINT (678262.808 -1462964.875, 678061.80...
# Processing availability 's' for institution 'KOPRI'
# Subset for availability 's':                                                  name   uri institution  \
# 2    KOPRI_KRT1_KHERA1B_2017030_DVG_IBH0c_GL0039d_000  None       KOPRI
# 3    KOPRI_KRT1_KHERA1B_2017030_DVG_IBH0c_GL0039d_001  None       KOPRI
# 4    KOPRI_KRT1_KHERA1B_2017030_DVG_IBH0c_GL0039d_002  None       KOPRI
# 5    KOPRI_KRT1_KHERA1B_2017030_DVG_IBH0c_GL0039d_003  None       KOPRI
# 6    KOPRI_KRT1_KHERA1B_2017033_DVG_IBH0c_GL0075a_000  None       KOPRI
# ..                                                ...   ...         ...
# 144     KOPRI_KRT1_KHERA1B_2017030_DVG_IBH0c_Y40a_000  None       KOPRI
# 145     KOPRI_KRT1_KHERA1B_2017030_DVG_IBH0c_Y40a_001  None       KOPRI
# 146     KOPRI_KRT1_KHERA1B_2017030_DVG_IBH0c_Y40a_002  None       KOPRI
# 147     KOPRI_KRT1_KHERA1B_2017033_DVG_IBH0c_Y41a_000  None       KOPRI
# 148     KOPRI_KRT1_KHERA1B_2017033_DVG_IBH0c_Y41a_001  None       KOPRI
#
#         region                                granule            segment  \
# 2    antarctic  KHERA1B_2017030_DVG_IBH0c_GL0039d_000  DVG_IBH0c_GL0039d
# 3    antarctic  KHERA1B_2017030_DVG_IBH0c_GL0039d_001  DVG_IBH0c_GL0039d
# 4    antarctic  KHERA1B_2017030_DVG_IBH0c_GL0039d_002  DVG_IBH0c_GL0039d
# 5    antarctic  KHERA1B_2017030_DVG_IBH0c_GL0039d_003  DVG_IBH0c_GL0039d
# 6    antarctic  KHERA1B_2017033_DVG_IBH0c_GL0075a_000  DVG_IBH0c_GL0075a
# ..         ...                                    ...                ...
# 144  antarctic     KHERA1B_2017030_DVG_IBH0c_Y40a_000     DVG_IBH0c_Y40a
# 145  antarctic     KHERA1B_2017030_DVG_IBH0c_Y40a_001     DVG_IBH0c_Y40a
# 146  antarctic     KHERA1B_2017030_DVG_IBH0c_Y40a_002     DVG_IBH0c_Y40a
# 147  antarctic     KHERA1B_2017033_DVG_IBH0c_Y41a_000     DVG_IBH0c_Y41a
# 148  antarctic     KHERA1B_2017033_DVG_IBH0c_Y41a_001     DVG_IBH0c_Y41a
#
#     campaign availability                                           geometry
# 2       KRT1            s  LINESTRING (666844.797 -1516016.192, 666277.20...
# 3       KRT1            s  LINESTRING (644158.336 -1489975.409, 643065.36...
# 4       KRT1            s  LINESTRING (623517.368 -1465581.110, 622903.50...
# 5       KRT1            s  LINESTRING (603652.602 -1441804.284, 603476.87...
# 6       KRT1            s  LINESTRING (624051.057 -1435568.356, 624195.22...
# ..       ...          ...                                                ...
# 144     KRT1            s  LINESTRING (567091.466 -1462811.878, 567190.93...
# 145     KRT1            s  LINESTRING (575291.754 -1506942.858, 575367.95...
# 146     KRT1            s  LINESTRING (582967.643 -1550413.141, 583102.05...
# 147     KRT1            s  LINESTRING (584375.474 -1530274.778, 584376.43...
# 148     KRT1            s  LINESTRING (578639.543 -1496607.837, 578461.53...
#
# [147 rows x 9 columns]
# Saved map for KOPRI to ./data3/Antarctica_coverage_KOPRI.png
#
# Processing institution: LDEO
# Checking layer: LDEO_2007_Recovery-Lakes
# Layer 'LDEO_2007_Recovery-Lakes' contains 'LDEO'.
# Checking layer: LDEO_2015_ROSETTA
# Layer 'LDEO_2015_ROSETTA' contains 'LDEO'.
# Checking layer: AGAP_GAMBIT
# Layer 'AGAP_GAMBIT' contains 'LDEO'.
# Processing availability 'u' for institution 'LDEO'
# Subset for availability 'u':                        name   uri institution     region granule segment  \
# 0  LDEO_2007_Recovery-Lakes  None        LDEO  antarctic    None    None
# 1         LDEO_2015_ROSETTA  None        LDEO  antarctic    None    None
#
#               campaign availability  \
# 0  2007_Recovery-Lakes            u
# 1         2015_ROSETTA            u
#
#                                             geometry
# 0  MULTIPOINT (574071.374 145100.759, 573934.226 ...
# 1  MULTIPOINT (-250336.863 -630280.086, -250128.3...
# Processing availability 's' for institution 'LDEO'
# Subset for availability 's':                                          name   uri institution     region  \
# 2     LDEO_AGAP_GAMBIT_F20a_F10130-079_1D_SAR  None        LDEO  antarctic
# 3     LDEO_AGAP_GAMBIT_F20a_F10130-080_1D_SAR  None        LDEO  antarctic
# 4     LDEO_AGAP_GAMBIT_F20a_F10130-081_1D_SAR  None        LDEO  antarctic
# 5     LDEO_AGAP_GAMBIT_F20a_F10130-082_1D_SAR  None        LDEO  antarctic
# 6     LDEO_AGAP_GAMBIT_F20a_F10130-083_1D_SAR  None        LDEO  antarctic
# ...                                       ...   ...         ...        ...
# 9683  LDEO_AGAP_GAMBIT_F26b_V10230-348_1D_SAR  None        LDEO  antarctic
# 9684  LDEO_AGAP_GAMBIT_F26b_V10230-349_1D_SAR  None        LDEO  antarctic
# 9685  LDEO_AGAP_GAMBIT_F26b_V10230-350_1D_SAR  None        LDEO  antarctic
# 9686  LDEO_AGAP_GAMBIT_F26b_V10230-351_1D_SAR  None        LDEO  antarctic
# 9687  LDEO_AGAP_GAMBIT_F26b_V10230-352_1D_SAR  None        LDEO  antarctic
#
#                      granule segment     campaign availability  \
# 2     F20a_F10130-079_1D_SAR  F10130  AGAP_GAMBIT            s
# 3     F20a_F10130-080_1D_SAR  F10130  AGAP_GAMBIT            s
# 4     F20a_F10130-081_1D_SAR  F10130  AGAP_GAMBIT            s
# 5     F20a_F10130-082_1D_SAR  F10130  AGAP_GAMBIT            s
# 6     F20a_F10130-083_1D_SAR  F10130  AGAP_GAMBIT            s
# ...                      ...     ...          ...          ...
# 9683  F26b_V10230-348_1D_SAR  V10230  AGAP_GAMBIT            s
# 9684  F26b_V10230-349_1D_SAR  V10230  AGAP_GAMBIT            s
# 9685  F26b_V10230-350_1D_SAR  V10230  AGAP_GAMBIT            s
# 9686  F26b_V10230-351_1D_SAR  V10230  AGAP_GAMBIT            s
# 9687  F26b_V10230-352_1D_SAR  V10230  AGAP_GAMBIT            s
#
#                                                geometry
# 2     LINESTRING (715413.164 288025.482, 715198.133 ...
# 3     LINESTRING (714821.955 291445.444, 714433.399 ...
# 4     LINESTRING (714202.962 294899.913, 714003.407 ...
# 5     LINESTRING (713577.233 298370.099, 713335.431 ...
# 6     LINESTRING (712972.340 301827.281, 712846.233 ...
# ...                                                 ...
# 9683  LINESTRING (1083082.191 106964.006, 1082812.58...
# 9684  LINESTRING (1082461.574 110552.526, 1082043.01...
# 9685  LINESTRING (1081828.113 114126.320, 1081705.46...
# 9686  LINESTRING (1082158.166 117672.246, 1082314.86...
# 9687  LINESTRING (1084977.541 120013.507, 1085609.93...
#
# [9686 rows x 9 columns]
# Saved map for LDEO to ./data3/Antarctica_coverage_LDEO.png
#
# Processing institution: NASA
# Checking layer: NASA_2002_ICEBRIDGE
# Layer 'NASA_2002_ICEBRIDGE' contains 'NASA'.
# Processing availability 'u' for institution 'NASA'
# Subset for availability 'u':                   name   uri institution     region granule segment  \
# 0  NASA_2002_ICEBRIDGE  None        NASA  antarctic    None    None
#
#          campaign availability  \
# 0  2002_ICEBRIDGE            u
#
#                                             geometry
# 0  MULTIPOINT (-2416484.578 1517876.257, -2416254...
# Saved map for NASA to ./data3/Antarctica_coverage_NASA.png
#
# Processing institution: NIPR
# Checking layer: NIPR_1992_JARE33
# Layer 'NIPR_1992_JARE33' contains 'NIPR'.
# Checking layer: NIPR_1996_JARE37
# Layer 'NIPR_1996_JARE37' contains 'NIPR'.
# Checking layer: NIPR_1999_JARE40
# Layer 'NIPR_1999_JARE40' contains 'NIPR'.
# Checking layer: NIPR_2007_JARE49
# Layer 'NIPR_2007_JARE49' contains 'NIPR'.
# Checking layer: NIPR_2007_JASE
# Layer 'NIPR_2007_JASE' contains 'NIPR'.
# Checking layer: NIPR_2012_JARE54
# Layer 'NIPR_2012_JARE54' contains 'NIPR'.
# Checking layer: NIPR_2017_JARE59
# Layer 'NIPR_2017_JARE59' contains 'NIPR'.
# Checking layer: NIPR_2018_JARE60
# Layer 'NIPR_2018_JARE60' contains 'NIPR'.
# Processing availability 'u' for institution 'NIPR'
# Subset for availability 'u':                name   uri institution     region granule segment     campaign  \
# 0  NIPR_1992_JARE33  None        NIPR  antarctic    None    None  1992_JARE33
# 1  NIPR_1996_JARE37  None        NIPR  antarctic    None    None  1996_JARE37
# 2  NIPR_1999_JARE40  None        NIPR  antarctic    None    None  1999_JARE40
# 3  NIPR_2007_JARE49  None        NIPR  antarctic    None    None  2007_JARE49
# 4    NIPR_2007_JASE  None        NIPR  antarctic    None    None    2007_JASE
# 5  NIPR_2012_JARE54  None        NIPR  antarctic    None    None  2012_JARE54
# 6  NIPR_2017_JARE59  None        NIPR  antarctic    None    None  2017_JARE59
# 7  NIPR_2018_JARE60  None        NIPR  antarctic    None    None  2018_JARE60
#
#   availability                                           geometry
# 0            u  MULTIPOINT (844090.367 1037542.523, 844370.803...
# 1            u  MULTIPOINT (755918.262 974699.575, 756187.967 ...
# 2            u  MULTIPOINT (883548.099 1064518.547, 883758.334...
# 3            u  MULTIPOINT (834927.154 1083979.311, 835196.495...
# 4            u  MULTIPOINT (16309.061 1636724.783, 16549.371 1...
# 5            u  MULTIPOINT (830251.665 1027099.481, 830498.234...
# 6            u  MULTIPOINT (794866.920 1001652.640, 794931.729...
# 7            u  MULTIPOINT (810960.082 1018919.963, 810986.174...
# Saved map for NIPR to ./data3/Antarctica_coverage_NIPR.png
#
# Processing institution: NPI
# Checking layer: NPI_2008_BELISSIMA
# Layer 'NPI_2008_BELISSIMA' contains 'NPI'.
# Checking layer: NPI_2010_SRM
# Layer 'NPI_2010_SRM' contains 'NPI'.
# Checking layer: NPI_2012_ICERISES
# Layer 'NPI_2012_ICERISES' contains 'NPI'.
# Checking layer: NPI_2015_POLARGAP
# Layer 'NPI_2015_POLARGAP' contains 'NPI'.
# Checking layer: NPI_2016_MADICE
# Layer 'NPI_2016_MADICE' contains 'NPI'.
# Processing availability 'u' for institution 'NPI'
# Subset for availability 'u':                  name   uri institution     region granule segment  \
# 0  NPI_2008_BELISSIMA  None         NPI  antarctic    None    None
# 1        NPI_2010_SRM  None         NPI  antarctic    None    None
# 2   NPI_2012_ICERISES  None         NPI  antarctic    None    None
# 3   NPI_2015_POLARGAP  None         NPI  antarctic    None    None
# 4     NPI_2016_MADICE  None         NPI  antarctic    None    None
#
#          campaign availability  \
# 0  2008_BELISSIMA            u
# 1        2010_SRM            u
# 2   2012_ICERISES            u
# 3   2015_POLARGAP            u
# 4     2016_MADICE            u
#
#                                             geometry
# 0  MULTIPOINT (872232.958 1950677.534, 872097.791...
# 1  MULTIPOINT (934093.732 1715714.509, 934229.287...
# 2  MULTIPOINT (103579.904 2143034.478, 103706.941...
# 3  MULTIPOINT (247092.214 694303.781, 247014.137 ...
# 4  MULTIPOINT (346990.290 2146229.929, 347191.717...
# Saved map for NPI to ./data3/Antarctica_coverage_NPI.png
#
# Processing institution: PRIC
# Checking layer: PRIC_2004_CHINARE-21
# Layer 'PRIC_2004_CHINARE-21' contains 'PRIC'.
# Checking layer: PRIC_2007_CHINARE-24
# Layer 'PRIC_2007_CHINARE-24' contains 'PRIC'.
# Checking layer: PRIC_2015_CHA1
# Layer 'PRIC_2015_CHA1' contains 'PRIC'.
# Checking layer: PRIC_2016_CHA2
# Layer 'PRIC_2016_CHA2' contains 'PRIC'.
# Checking layer: PRIC_2017_CHA3
# Layer 'PRIC_2017_CHA3' contains 'PRIC'.
# Checking layer: PRIC_2018_CHA4
# Layer 'PRIC_2018_CHA4' contains 'PRIC'.
# Processing availability 'u' for institution 'PRIC'
# Subset for availability 'u':                    name   uri institution     region granule segment  \
# 0  PRIC_2004_CHINARE-21  None        PRIC  antarctic    None    None
# 1  PRIC_2007_CHINARE-24  None        PRIC  antarctic    None    None
# 2        PRIC_2015_CHA1  None        PRIC  antarctic    None    None
# 3        PRIC_2016_CHA2  None        PRIC  antarctic    None    None
# 4        PRIC_2017_CHA3  None        PRIC  antarctic    None    None
# 5        PRIC_2018_CHA4  None        PRIC  antarctic    None    None
#
#           campaign availability  \
# 0  2004_CHINARE-21            u
# 1  2007_CHINARE-24            u
# 2        2015_CHA1            u
# 3        2016_CHA2            u
# 4        2017_CHA3            u
# 5        2018_CHA4            u
#
#                                             geometry
# 0  MULTIPOINT (2047968.345 469999.216, 2047742.93...
# 1  MULTIPOINT (1034716.904 220937.076, 1034745.45...
# 2  MULTIPOINT (2193362.185 534019.070, 2193529.77...
# 3  MULTIPOINT (2356444.957 -862291.628, 2356287.5...
# 4  MULTIPOINT (2205056.066 532529.125, 2205251.46...
# 5  MULTIPOINT (2198383.580 530423.657, 2198520.32...
# Saved map for PRIC to ./data3/Antarctica_coverage_PRIC.png
#
# Processing institution: RNRF
# Checking layer: RNRF_1971_Lambert-Amery
# Layer 'RNRF_1971_Lambert-Amery' contains 'RNRF'.
# Checking layer: RNRF_1975_Filchner-Ronne
# Layer 'RNRF_1975_Filchner-Ronne' contains 'RNRF'.
# Checking layer: RNRF_1975_Lazarev
# Layer 'RNRF_1975_Lazarev' contains 'RNRF'.
# Checking layer: RNRF_2003_48RAEap5
# Layer 'RNRF_2003_48RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2003_AMSap5
# Layer 'RNRF_2003_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2004_49RAEap5
# Layer 'RNRF_2004_49RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2004_AMSap5
# Layer 'RNRF_2004_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2004_Mirny-Vostok
# Layer 'RNRF_2004_Mirny-Vostok' contains 'RNRF'.
# Checking layer: RNRF_2005_50RAEap5
# Layer 'RNRF_2005_50RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2005_AMSap5
# Layer 'RNRF_2005_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2006_51RAEap5
# Layer 'RNRF_2006_51RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2006_KV1-area
# Layer 'RNRF_2006_KV1-area' contains 'RNRF'.
# Checking layer: RNRF_2006_Komsom-Vostok
# Layer 'RNRF_2006_Komsom-Vostok' contains 'RNRF'.
# Checking layer: RNRF_2006_RAEap5
# Layer 'RNRF_2006_RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2007_52RAEap5
# Layer 'RNRF_2007_52RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2007_AMSap5
# Layer 'RNRF_2007_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2007_Mirny-Vostok
# Layer 'RNRF_2007_Mirny-Vostok' contains 'RNRF'.
# Checking layer: RNRF_2008_53RAEap5
# Layer 'RNRF_2008_53RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2008_AMSap5
# Layer 'RNRF_2008_AMSap5' contains 'RNRF'.
# Checking layer: RNRF_2008_Vostok-Subglacial-Lake
# Layer 'RNRF_2008_Vostok-Subglacial-Lake' contains 'RNRF'.
# Checking layer: RNRF_2009_RAEap5
# Layer 'RNRF_2009_RAEap5' contains 'RNRF'.
# Checking layer: RNRF_2010_RAE
# Layer 'RNRF_2010_RAE' contains 'RNRF'.
# Checking layer: RNRF_2011_RAE
# Layer 'RNRF_2011_RAE' contains 'RNRF'.
# Checking layer: RNRF_2013_RAE
# Layer 'RNRF_2013_RAE' contains 'RNRF'.
# Checking layer: RNRF_2013_Vostok-Progress
# Layer 'RNRF_2013_Vostok-Progress' contains 'RNRF'.
# Checking layer: RNRF_2014_RAE
# Layer 'RNRF_2014_RAE' contains 'RNRF'.
# Checking layer: RNRF_2015_RAE
# Layer 'RNRF_2015_RAE' contains 'RNRF'.
# Checking layer: RNRF_2016_RAE
# Layer 'RNRF_2016_RAE' contains 'RNRF'.
# Checking layer: RNRF_2017_RAE
# Layer 'RNRF_2017_RAE' contains 'RNRF'.
# Checking layer: RNRF_2018_RAE
# Layer 'RNRF_2018_RAE' contains 'RNRF'.
# Checking layer: RNRF_2019_RAE
# Layer 'RNRF_2019_RAE' contains 'RNRF'.
# Processing availability 'u' for institution 'RNRF'
# Subset for availability 'u':                                 name   uri institution     region granule  \
# 0            RNRF_1971_Lambert-Amery  None        RNRF  antarctic    None
# 1           RNRF_1975_Filchner-Ronne  None        RNRF  antarctic    None
# 2                  RNRF_1975_Lazarev  None        RNRF  antarctic    None
# 3                 RNRF_2003_48RAEap5  None        RNRF  antarctic    None
# 4                   RNRF_2003_AMSap5  None        RNRF  antarctic    None
# 5                 RNRF_2004_49RAEap5  None        RNRF  antarctic    None
# 6                   RNRF_2004_AMSap5  None        RNRF  antarctic    None
# 7             RNRF_2004_Mirny-Vostok  None        RNRF  antarctic    None
# 8                 RNRF_2005_50RAEap5  None        RNRF  antarctic    None
# 9                   RNRF_2005_AMSap5  None        RNRF  antarctic    None
# 10                RNRF_2006_51RAEap5  None        RNRF  antarctic    None
# 11                RNRF_2006_KV1-area  None        RNRF  antarctic    None
# 12           RNRF_2006_Komsom-Vostok  None        RNRF  antarctic    None
# 13                  RNRF_2006_RAEap5  None        RNRF  antarctic    None
# 14                RNRF_2007_52RAEap5  None        RNRF  antarctic    None
# 15                  RNRF_2007_AMSap5  None        RNRF  antarctic    None
# 16            RNRF_2007_Mirny-Vostok  None        RNRF  antarctic    None
# 17                RNRF_2008_53RAEap5  None        RNRF  antarctic    None
# 18                  RNRF_2008_AMSap5  None        RNRF  antarctic    None
# 19  RNRF_2008_Vostok-Subglacial-Lake  None        RNRF  antarctic    None
# 20                  RNRF_2009_RAEap5  None        RNRF  antarctic    None
# 21                     RNRF_2010_RAE  None        RNRF  antarctic    None
# 22                     RNRF_2011_RAE  None        RNRF  antarctic    None
# 23                     RNRF_2013_RAE  None        RNRF  antarctic    None
# 24         RNRF_2013_Vostok-Progress  None        RNRF  antarctic    None
# 25                     RNRF_2014_RAE  None        RNRF  antarctic    None
# 26                     RNRF_2015_RAE  None        RNRF  antarctic    None
# 27                     RNRF_2016_RAE  None        RNRF  antarctic    None
# 28                     RNRF_2017_RAE  None        RNRF  antarctic    None
# 29                     RNRF_2018_RAE  None        RNRF  antarctic    None
# 30                     RNRF_2019_RAE  None        RNRF  antarctic    None
#
#    segment                     campaign availability  \
# 0     None           1971_Lambert-Amery            u
# 1     None          1975_Filchner-Ronne            u
# 2     None                 1975_Lazarev            u
# 3     None                2003_48RAEap5            u
# 4     None                  2003_AMSap5            u
# 5     None                2004_49RAEap5            u
# 6     None                  2004_AMSap5            u
# 7     None            2004_Mirny-Vostok            u
# 8     None                2005_50RAEap5            u
# 9     None                  2005_AMSap5            u
# 10    None                2006_51RAEap5            u
# 11    None                2006_KV1-area            u
# 12    None           2006_Komsom-Vostok            u
# 13    None                  2006_RAEap5            u
# 14    None                2007_52RAEap5            u
# 15    None                  2007_AMSap5            u
# 16    None            2007_Mirny-Vostok            u
# 17    None                2008_53RAEap5            u
# 18    None                  2008_AMSap5            u
# 19    None  2008_Vostok-Subglacial-Lake            u
# 20    None                  2009_RAEap5            u
# 21    None                     2010_RAE            u
# 22    None                     2011_RAE            u
# 23    None                     2013_RAE            u
# 24    None         2013_Vostok-Progress            u
# 25    None                     2014_RAE            u
# 26    None                     2015_RAE            u
# 27    None                     2016_RAE            u
# 28    None                     2017_RAE            u
# 29    None                     2018_RAE            u
# 30    None                     2019_RAE            u
#
#                                              geometry
# 0   MULTIPOINT (2252772.349 911627.909, 2203335.06...
# 1   MULTIPOINT (-713926.836 1307895.328, -1166831....
# 2   MULTIPOINT (557742.537 2201478.644, 557100.848...
# 3   MULTIPOINT (2150724.686 500918.979, 2150810.65...
# 4   MULTIPOINT (2175238.086 493072.991, 2174967.23...
# 5   MULTIPOINT (2004041.831 895596.183, 2003947.71...
# 6   MULTIPOINT (2004408.294 894896.328, 2004315.11...
# 7   MULTIPOINT (2576701.898 -134369.805, 2576539.9...
# 8   MULTIPOINT (2075143.036 296903.419, 2075072.23...
# 9   MULTIPOINT (2075168.515 296839.265, 2075093.01...
# 10  MULTIPOINT (2254119.410 260680.807, 2254118.18...
# 11  MULTIPOINT (1723288.061 -177047.027, 1723494.0...
# 12  MULTIPOINT (1723279.062 -177048.027, 1723483.0...
# 13  MULTIPOINT (2240160.268 363140.166, 2240397.31...
# 14  MULTIPOINT (1648187.483 801947.611, 1648071.48...
# 15  MULTIPOINT (1648210.481 801903.612, 1648095.48...
# 16  MULTIPOINT (2326674.031 -185451.974, 2326871.0...
# 17  MULTIPOINT (1862788.949 889711.169, 1862695.95...
# 18  MULTIPOINT (1862808.948 889669.170, 1862705.95...
# 19  MULTIPOINT (1295813.724 -296830.959, 1294857.4...
# 20  MULTIPOINT (2165341.360 1158682.001, 2165454.2...
# 21  MULTIPOINT (2182842.027 488691.462, 2182790.85...
# 22  MULTIPOINT (2024029.774 473856.785, 2024100.48...
# 23  MULTIPOINT (2252582.342 337114.261, 2252582.28...
# 24  MULTIPOINT (1217804.388 -309803.756, 1217991.3...
# 25  MULTIPOINT (2363280.255 286679.599, 2363300.29...
# 26  MULTIPOINT (2467396.781 78536.544, 2467201.757...
# 27  MULTIPOINT (2256534.234 215458.528, 2256585.37...
# 28  MULTIPOINT (2467391.587 -100937.064, 2467170.4...
# 29  MULTIPOINT (2355906.120 55379.261, 2355902.243...
# 30  MULTIPOINT (2478003.067 -266144.041, 2478018.1...
# Saved map for RNRF to ./data3/Antarctica_coverage_RNRF.png
#
# Processing institution: STOLAF
# Checking layer: STOLAF_1994_Siple-Dome
# Layer 'STOLAF_1994_Siple-Dome' contains 'STOLAF'.
# Checking layer: STOLAF_2001_ITASE-Byrd-Ellsworth
# Layer 'STOLAF_2001_ITASE-Byrd-Ellsworth' contains 'STOLAF'.
# Checking layer: STOLAF_2001_ITASE-Ellsworth
# Layer 'STOLAF_2001_ITASE-Ellsworth' contains 'STOLAF'.
# Checking layer: STOLAF_2002_ITASE-Byrd-South-Pole
# Layer 'STOLAF_2002_ITASE-Byrd-South-Pole' contains 'STOLAF'.
# Checking layer: STOLAF_2002_ITASE-Hercules-Dome
# Layer 'STOLAF_2002_ITASE-Hercules-Dome' contains 'STOLAF'.
# Processing availability 'u' for institution 'STOLAF'
# Subset for availability 'u':                                 name   uri institution     region granule  \
# 0             STOLAF_1994_Siple-Dome  None      STOLAF  antarctic    None
# 1   STOLAF_2001_ITASE-Byrd-Ellsworth  None      STOLAF  antarctic    None
# 2        STOLAF_2001_ITASE-Ellsworth  None      STOLAF  antarctic    None
# 3  STOLAF_2002_ITASE-Byrd-South-Pole  None      STOLAF  antarctic    None
# 4    STOLAF_2002_ITASE-Hercules-Dome  None      STOLAF  antarctic    None
#
#   segment                    campaign availability  \
# 0    None             1994_Siple-Dome            u
# ...
# Checking layer: 2004_Antarctica_P3chile
# Layer '2004_Antarctica_P3chile' contains 'CRESIS'.
# Checking layer: 2005_Antarctica_GPRWAIS
# Layer '2005_Antarctica_GPRWAIS' contains 'CRESIS'.
# Checking layer: 2009_Antarctica_DC8
# Layer '2009_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2009_Antarctica_TO
# Layer '2009_Antarctica_TO' contains 'CRESIS'.
# Checking layer: 2009_Antarctica_TO_Gambit
# Layer '2009_Antarctica_TO_Gambit' contains 'CRESIS'.
# Checking layer: 2010_Antarctica_DC8
# Layer '2010_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2011_Antarctica_DC8
# Layer '2011_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2011_Antarctica_TO
# Layer '2011_Antarctica_TO' contains 'CRESIS'.
# Checking layer: 2012_Antarctica_DC8
# Layer '2012_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2013_Antarctica_Basler
# Layer '2013_Antarctica_Basler' contains 'CRESIS'.
# Checking layer: 2013_Antarctica_P3
# Layer '2013_Antarctica_P3' contains 'CRESIS'.
# Checking layer: 2014_Antarctica_DC8
# Layer '2014_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2016_Antarctica_DC8
# Layer '2016_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2017_Antarctica_Basler
# Layer '2017_Antarctica_Basler' contains 'CRESIS'.
# Checking layer: 2017_Antarctica_P3
# Layer '2017_Antarctica_P3' contains 'CRESIS'.
# Checking layer: 2018_Antarctica_DC8
# Layer '2018_Antarctica_DC8' contains 'CRESIS'.
# Checking layer: 2018_Antarctica_Ground
# Layer '2018_Antarctica_Ground' contains 'CRESIS'.
# Checking layer: 2019_Antarctica_GV
# Layer '2019_Antarctica_GV' contains 'CRESIS'.
# Processing availability 's' for institution 'CRESIS'
# Subset for availability 's':      institution     region                 campaign      segment  \
# 0         CRESIS  antarctic  2002_Antarctica_P3chile  20021126_01
# 1         CRESIS  antarctic  2002_Antarctica_P3chile  20021126_01
# 2         CRESIS  antarctic  2002_Antarctica_P3chile  20021126_01
# 3         CRESIS  antarctic  2002_Antarctica_P3chile  20021126_01
# 4         CRESIS  antarctic  2002_Antarctica_P3chile  20021126_01
# ...          ...        ...                      ...          ...
# 9452      CRESIS  antarctic       2019_Antarctica_GV  20191120_04
# 9453      CRESIS  antarctic       2019_Antarctica_GV  20191120_04
# 9454      CRESIS  antarctic       2019_Antarctica_GV  20191120_04
# 9455      CRESIS  antarctic       2019_Antarctica_GV  20191120_04
# 9456      CRESIS  antarctic       2019_Antarctica_GV  20191120_04
#
#                    granule availability   uri  \
# 0     Data_20021126_01_001            s  None
# 1     Data_20021126_01_002            s  None
# 2     Data_20021126_01_003            s  None
# 3     Data_20021126_01_005            s  None
# 4     Data_20021126_01_006            s  None
# ...                    ...          ...   ...
# 9452  Data_20191120_04_023            s  None
# 9453  Data_20191120_04_024            s  None
# 9454  Data_20191120_04_025            s  None
# 9455  Data_20191120_04_026            s  None
# 9456  Data_20191120_04_027            s  None
#
#                                                    name  \
# 0     CRESIS_2002_Antarctica_P3chile_Data_20021126_0...
# 1     CRESIS_2002_Antarctica_P3chile_Data_20021126_0...
# 2     CRESIS_2002_Antarctica_P3chile_Data_20021126_0...
# 3     CRESIS_2002_Antarctica_P3chile_Data_20021126_0...
# 4     CRESIS_2002_Antarctica_P3chile_Data_20021126_0...
# ...                                                 ...
# 9452     CRESIS_2019_Antarctica_GV_Data_20191120_04_023
# 9453     CRESIS_2019_Antarctica_GV_Data_20191120_04_024
# 9454     CRESIS_2019_Antarctica_GV_Data_20191120_04_025
# 9455     CRESIS_2019_Antarctica_GV_Data_20191120_04_026
# 9456     CRESIS_2019_Antarctica_GV_Data_20191120_04_027
#
#                                                geometry
# 0     LINESTRING (-2416484.615 1517876.259, -2415900...
# 1     LINESTRING (-2413491.123 1525869.181, -2413112...
# 2     LINESTRING (-2407767.336 1269434.134, -2408995...
# 3     LINESTRING (-2297015.103 1041853.205, -2295984...
# 4     LINESTRING (-2181166.558 979703.262, -2180440....
# ...                                                 ...
# 9452  LINESTRING (1091805.515 -1890528.734, 1056642....
# 9453  LINESTRING (1041876.020 -1894891.234, 1032446....
# 9454  LINESTRING (992589.229 -1903824.953, 963071.18...
# 9455  LINESTRING (950089.476 -1922993.310, 949084.97...
# 9456  LINESTRING (931354.283 -1969456.760, 931168.16...
#
# [9457 rows x 9 columns]
# Saved map for CRESIS to ./data3/Antarctica_coverage_CRESIS.png
#
# Processing institution: STANFORD
# Checking layer: STANFORD_SPRI_NSF_TUD
# Layer 'STANFORD_SPRI_NSF_TUD' contains 'STANFORD'.
# Processing availability 'a' for institution 'STANFORD'
# Subset for availability 'a':    institution     region      campaign segment granule availability   uri  \
# 0     STANFORD  antarctic  SPRI_NSF_TUD     001     001            a  None
# 1     STANFORD  antarctic  SPRI_NSF_TUD     002     002            a  None
# 2     STANFORD  antarctic  SPRI_NSF_TUD     003     003            a  None
# 3     STANFORD  antarctic  SPRI_NSF_TUD     004     004            a  None
# 4     STANFORD  antarctic  SPRI_NSF_TUD     005     005            a  None
# ..         ...        ...           ...     ...     ...          ...   ...
# 56    STANFORD  antarctic  SPRI_NSF_TUD     144     144            a  None
# 57    STANFORD  antarctic  SPRI_NSF_TUD     145     145            a  None
# 58    STANFORD  antarctic  SPRI_NSF_TUD     147     147            a  None
# 59    STANFORD  antarctic  SPRI_NSF_TUD     148     148            a  None
# 60    STANFORD  antarctic  SPRI_NSF_TUD     149     149            a  None
#
#                          name  \
# 0   STANFORD_SPRI_NSF_TUD_001
# 1   STANFORD_SPRI_NSF_TUD_002
# 2   STANFORD_SPRI_NSF_TUD_003
# 3   STANFORD_SPRI_NSF_TUD_004
# 4   STANFORD_SPRI_NSF_TUD_005
# ..                        ...
# 56  STANFORD_SPRI_NSF_TUD_144
# 57  STANFORD_SPRI_NSF_TUD_145
# 58  STANFORD_SPRI_NSF_TUD_147
# 59  STANFORD_SPRI_NSF_TUD_148
# 60  STANFORD_SPRI_NSF_TUD_149
#
#                                              geometry
# 0   LINESTRING (-383942.570 -179773.402, -385413.3...
# 1   LINESTRING (-690924.170 -153372.843, -691798.6...
# 2   LINESTRING (555503.879 -664134.889, 555485.652...
# 3   LINESTRING (-556795.513 -130605.461, -558346.8...
# 4   LINESTRING (-1345914.420 -664099.543, -1347347...
# ..                                                ...
# 56  LINESTRING (299368.263 -1287812.571, 299496.53...
# 57  LINESTRING (299368.263 -1287812.571, 299368.00...
# 58  LINESTRING (299368.263 -1287812.571, 299364.28...
# 59  LINESTRING (-946971.817 -535818.812, -947015.2...
# 60  LINESTRING (299368.263 -1287812.571, 299370.07...
#
# [61 rows x 9 columns]
# Saved map for STANFORD to ./data3/Antarctica_coverage_STANFORD.png
# Processing availability 'u' for institution 'Overview'
# Subset for availability 'u':                                 name   uri  institution     region granule  \
# 0                      AWI_1994_DML1  None          AWI  antarctic    None
# 1                      AWI_1995_DML2  None          AWI  antarctic    None
# 2                      AWI_1996_DML3  None          AWI  antarctic    None
# 3                      AWI_1997_DML4  None          AWI  antarctic    None
# 4                      AWI_1998_DML5  None          AWI  antarctic    None
# ..                               ...   ...          ...        ...     ...
# 4                   UTIG_2008_ICECAP  None         UTIG  antarctic    None
# 5         UTIG_2009_Darwin-Hatherton  None         UTIG  antarctic    None
# 6                   UTIG_2010_ICECAP  None         UTIG  antarctic    None
# 7                   UTIG_2013_GIMBLE  None         UTIG  antarctic    None
# 0   UWASHINGTON_2018_South-Pole-Lake  None  UWASHINGTON  antarctic    None
#
#    segment               campaign availability  \
# 0     None              1994_DML1            u
# 1     None              1995_DML2            u
# 2     None              1996_DML3            u
# 3     None              1997_DML4            u
# 4     None              1998_DML5            u
# ..     ...                    ...          ...
# 4     None            2008_ICECAP            u
# 5     None  2009_Darwin-Hatherton            u
# 6     None            2010_ICECAP            u
# 7     None            2013_GIMBLE            u
# 0     None   2018_South-Pole-Lake            u
#
#                                              geometry data_citation  \
# 0   MULTIPOINT (-285560.755 1557735.604, -285182.1...           NaN
# 1   MULTIPOINT (665624.521 1734554.058, 665844.122...           NaN
# 2   MULTIPOINT (-394877.402 2040211.868, -394728.1...           NaN
# 3   MULTIPOINT (24872.282 1660804.497, 25215.086 1...           NaN
# 4   MULTIPOINT (97225.138 1400217.359, 97362.585 1...           NaN
# ..                                                ...           ...
# 4   MULTIPOINT (2405242.421 -942679.076, 2405056.9...           NaN
# 5   MULTIPOINT (361471.006 -1055829.079, 361558.67...           NaN
# 6   MULTIPOINT (1325763.066 -892240.873, 1325563.0...           NaN
# 7   MULTIPOINT (-953010.947 -541447.634, -952911.1...           NaN
# 0   MULTIPOINT (-6836.745 -6015.901, -6931.834 -61...           NaN
#
#    science_citation
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 0               NaN
#
# [450 rows x 11 columns]
# Processing availability 's' for institution 'Overview'
# Subset for availability 's':                                                 name   uri institution  \
# 16                                 BAS_AGAP_AGAP_A03  None         BAS
# 17                                 BAS_AGAP_AGAP_A04  None         BAS
# 18                                 BAS_AGAP_AGAP_A05  None         BAS
# 19                                BAS_AGAP_AGAP_A05A  None         BAS
# 20                                BAS_AGAP_AGAP_A06C  None         BAS
# ...                                              ...   ...         ...
# 9452  CRESIS_2019_Antarctica_GV_Data_20191120_04_023  None      CRESIS
# 9453  CRESIS_2019_Antarctica_GV_Data_20191120_04_024  None      CRESIS
# 9454  CRESIS_2019_Antarctica_GV_Data_20191120_04_025  None      CRESIS
# 9455  CRESIS_2019_Antarctica_GV_Data_20191120_04_026  None      CRESIS
# 9456  CRESIS_2019_Antarctica_GV_Data_20191120_04_027  None      CRESIS
#
#          region               granule      segment            campaign  \
# 16    antarctic              AGAP_A03     AGAP_A03                AGAP
# 17    antarctic              AGAP_A04     AGAP_A04                AGAP
# 18    antarctic              AGAP_A05     AGAP_A05                AGAP
# 19    antarctic             AGAP_A05A    AGAP_A05A                AGAP
# 20    antarctic             AGAP_A06C    AGAP_A06C                AGAP
# ...         ...                   ...          ...                 ...
# 9452  antarctic  Data_20191120_04_023  20191120_04  2019_Antarctica_GV
# 9453  antarctic  Data_20191120_04_024  20191120_04  2019_Antarctica_GV
# 9454  antarctic  Data_20191120_04_025  20191120_04  2019_Antarctica_GV
# 9455  antarctic  Data_20191120_04_026  20191120_04  2019_Antarctica_GV
# 9456  antarctic  Data_20191120_04_027  20191120_04  2019_Antarctica_GV
#
#      availability                                           geometry  \
# 16              s  LINESTRING (249729.016 -1305354.471, 249179.82...
# 17              s  LINESTRING (260421.894 -1197599.389, 260348.55...
# 18              s  LINESTRING (265616.817 -685957.302, 265653.872...
# 19              s  LINESTRING (127506.382 -258418.054, 127211.708...
# 20              s  LINESTRING (-44410.750 -17539.299, -44626.876 ...
# ...           ...                                                ...
# 9452            s  LINESTRING (1091805.515 -1890528.734, 1056642....
# 9453            s  LINESTRING (1041876.020 -1894891.234, 1032446....
# 9454            s  LINESTRING (992589.229 -1903824.953, 963071.18...
# 9455            s  LINESTRING (950089.476 -1922993.310, 949084.97...
# 9456            s  LINESTRING (931354.283 -1969456.760, 931168.16...
#
#      data_citation science_citation
# 16             NaN              NaN
# 17             NaN              NaN
# 18             NaN              NaN
# 19             NaN              NaN
# 20             NaN              NaN
# ...            ...              ...
# 9452           NaN              NaN
# 9453           NaN              NaN
# 9454           NaN              NaN
# 9455           NaN              NaN
# 9456           NaN              NaN
#
# [23995 rows x 11 columns]
# Processing availability 'nan' for institution 'Overview'
# Subset for availability 'nan': Empty GeoDataFrame
# Columns: [name, uri, institution, region, granule, segment, campaign, availability, geometry, data_citation, science_citation]
# Index: []
# Processing availability 'a' for institution 'Overview'
# Subset for availability 'a':                          name   uri institution     region granule segment  \
# 0   STANFORD_SPRI_NSF_TUD_001  None    STANFORD  antarctic     001     001
# 1   STANFORD_SPRI_NSF_TUD_002  None    STANFORD  antarctic     002     002
# 2   STANFORD_SPRI_NSF_TUD_003  None    STANFORD  antarctic     003     003
# 3   STANFORD_SPRI_NSF_TUD_004  None    STANFORD  antarctic     004     004
# 4   STANFORD_SPRI_NSF_TUD_005  None    STANFORD  antarctic     005     005
# ..                        ...   ...         ...        ...     ...     ...
# 56  STANFORD_SPRI_NSF_TUD_144  None    STANFORD  antarctic     144     144
# 57  STANFORD_SPRI_NSF_TUD_145  None    STANFORD  antarctic     145     145
# 58  STANFORD_SPRI_NSF_TUD_147  None    STANFORD  antarctic     147     147
# 59  STANFORD_SPRI_NSF_TUD_148  None    STANFORD  antarctic     148     148
# 60  STANFORD_SPRI_NSF_TUD_149  None    STANFORD  antarctic     149     149
#
#         campaign availability  \
# 0   SPRI_NSF_TUD            a
# 1   SPRI_NSF_TUD            a
# 2   SPRI_NSF_TUD            a
# 3   SPRI_NSF_TUD            a
# 4   SPRI_NSF_TUD            a
# ..           ...          ...
# 56  SPRI_NSF_TUD            a
# 57  SPRI_NSF_TUD            a
# 58  SPRI_NSF_TUD            a
# 59  SPRI_NSF_TUD            a
# 60  SPRI_NSF_TUD            a
#
#                                              geometry data_citation  \
# 0   LINESTRING (-383942.570 -179773.402, -385413.3...           NaN
# 1   LINESTRING (-690924.170 -153372.843, -691798.6...           NaN
# 2   LINESTRING (555503.879 -664134.889, 555485.652...           NaN
# 3   LINESTRING (-556795.513 -130605.461, -558346.8...           NaN
# 4   LINESTRING (-1345914.420 -664099.543, -1347347...           NaN
# ..                                                ...           ...
# 56  LINESTRING (299368.263 -1287812.571, 299496.53...           NaN
# 57  LINESTRING (299368.263 -1287812.571, 299368.00...           NaN
# 58  LINESTRING (299368.263 -1287812.571, 299364.28...           NaN
# 59  LINESTRING (-946971.817 -535818.812, -947015.2...           NaN
# 60  LINESTRING (299368.263 -1287812.571, 299370.07...           NaN
#
#    science_citation
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 56              NaN
# 57              NaN
# 58              NaN
# 59              NaN
# 60              NaN
#
# [61 rows x 11 columns]
# /var/folders/vv/czt16t1x4_12h0xsl6rcd5_80000gn/T/ipykernel_14387/2103577489.py:63: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   subset.plot(ax=ax, color=color, markersize=.55, linewidth=0.25, label=label)
# Saved map for Overview to ./data3/Antarctica_coverage_overview.png
# All maps have been created and saved to the data3 folder.
