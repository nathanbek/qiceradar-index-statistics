# %%
import geopandas as gpd
import pandas as pd
import os
import fiona
from matplotlib_scalebar.scalebar import ScaleBar
import matplotlib.pyplot as plt

# Define the paths
input_file_path = "./antarctic_index.gpkg"
map_path = "/Users/nathanbekele/Downloads/Quantarctica3/Miscellaneous/SimpleBasemap/ADD_DerivedLowresBasemap.shp"
output_folder = "./data3"
statistics_folder = "./data_statistics"

# Ensure the output folders exist
os.makedirs(output_folder, exist_ok=True)
os.makedirs(statistics_folder, exist_ok=True)

fp = gpd.read_file(input_file_path)
print(fp.head())
print(fp.tail())

print(fp['geometry'].tolist())
print("CRS of the GeoPackage:", g.crs)
# Out:
#             name   uri institution     region granule segment   campaign  \
# 0  AWI_1994_DML1  None         AWI  antarctic    None    None  1994_DML1
#
#   availability                                           geometry
# 0            u  MULTIPOINT (-285560.755 1557735.604, -285182.1...
#             name   uri institution     region granule segment   campaign  \
# 0  AWI_1994_DML1  None         AWI  antarctic    None    None  1994_DML1
#
#   availability                                           geometry
# 0            u  MULTIPOINT (-285560.755 1557735.604, -285182.1...
# [<MULTIPOINT (-285560.755 1557735.604, -285182.186 1557356.256, -284979.372 1...>]
# CRS of the GeoPackage: EPSG:3031

# %%
import geopandas as gpd
import pandas as pd
import os
from shapely.geometry import MultiPoint, LineString, Point
import fiona

# Define the paths to the input and output files
input_file_path = "./antarctic_index.gpkg"
map_path = "/Users/nathanbekele/Downloads/Quantarctica3/Miscellaneous/SimpleBasemap/ADD_DerivedLowresBasemap.shp"
output_folder = "./data3"
statistics_folder = "./data_statistics"

# Ensure the output folders exist
os.makedirs(output_folder, exist_ok=True)
os.makedirs(statistics_folder, exist_ok=True)

# Function to calculate distance from geometries
def calculate_distance(geometry):
    if isinstance(geometry, MultiPoint):
        points = [point for point in geometry.geoms]
        line = LineString(points)
        return round(line.length / 1000, 2)  # Convert meters to kilometers and round to hundredth
    elif isinstance(geometry, LineString):
        return round(geometry.length / 1000, 2)  # Convert meters to kilometers and round to hundredth
    elif isinstance(geometry, Point):
        return 0  # A single point has no length
    else:
        return 0  # Handle other geometry types accordingly

# Function to determine availability status
def determine_availability(row):
    if row['availability'] == 's':
        return 'yes'
    elif row['availability'] == 'u':
        return 'no'
    else:
        return 'outdated'

# List all layers in the GeoPackage
layers = fiona.listlayers(input_file_path)
all_statistics = []

# Process each layer in the GeoPackage
institution_summary = {}
for layer in layers:
    try:
        gdf = gpd.read_file(input_file_path, layer=layer)
    except Exception as e:
        print(f"Skipping layer {layer} due to read error: {e}")
        continue

    if 'institution' not in gdf.columns:
        print(f"Skipping layer {layer} as it does not contain 'institution' column.")
        continue

    print(f"Processing layer: {layer}")

    # Ensure the CRS is set to EPSG:3031 if not already set
    if gdf.crs is None:
        gdf.set_crs("EPSG:3031", inplace=True)

    # Ensure the CRS is Antarctic Polar Stereographic and convert distances
    if gdf.crs != "EPSG:3031":
        gdf = gdf.to_crs("EPSG:3031")

    # Calculate distances for each row
    gdf['total_distance_km'] = gdf['geometry'].apply(calculate_distance)

    # Calculate available distance based on availability status
    if 'availability' in gdf.columns:
        gdf['available_distance_km'] = gdf.apply(
            lambda row: calculate_distance(row['geometry']) if row['availability'] == 's' else 0, axis=1
        )
        gdf['availability'] = gdf.apply(determine_availability, axis=1)
    else:
        gdf['available_distance_km'] = 0
        gdf['availability'] = 'outdated'

    # Ensure 'campaign' column exists, adding it with default value 'Unknown' if missing
    if 'campaign' not in gdf.columns:
        gdf['campaign'] = 'Unknown'

    # Group by institution and campaign to calculate statistics
    grouped = gdf.groupby(['institution', 'campaign']).agg({
        'total_distance_km': 'sum',
        'available_distance_km': 'sum'
    }).reset_index()

    # Process each institution in the grouped data
    for institution, institution_data in grouped.groupby('institution'):
        if institution not in institution_summary:
            institution_summary[institution] = []

        institution_summary[institution].append(institution_data)

        # Prepare the DataFrame for institution CSV
        institution_df = pd.concat(institution_summary[institution], ignore_index=True)
        institution_total = institution_df.agg({
            'total_distance_km': 'sum',
            'available_distance_km': 'sum'
        }).to_frame().T
        institution_total['campaign'] = 'Total'
        institution_total['institution'] = institution
        institution_total['availability'] = 'N/A'  # Availability does not apply to the total row
        institution_df = pd.concat([institution_df, institution_total], ignore_index=True)

        # Save each institution's data to a CSV
        institution_output_path = os.path.join(statistics_folder, f'statistics_{institution}.csv')
        institution_df.to_csv(institution_output_path, index=False)
        print(f"Saved statistics for {institution} to {institution_output_path}")

    # Append the statistics to the all_statistics list for overall summary
    all_statistics.append(grouped)

# Combine all statistics into a single DataFrame for the overview
all_statistics_df = pd.concat(all_statistics, ignore_index=True)

# Group by institution to sum totals for the overview
overview_df = all_statistics_df.groupby('institution').agg({
    'total_distance_km': 'sum',
    'available_distance_km': 'sum'
}).reset_index()

# Save the overview statistics to a CSV
overview_output_path = os.path.join(statistics_folder, 'institution_overview.csv')
overview_df.to_csv(overview_output_path, index=False)
print(f"Saved institution overview statistics to {overview_output_path}")

# Display the overview statistics
print("\nInstitution Overview Statistics:")
print(overview_df)

# Display the complete statistics table
print("\nComplete statistics table:")
print(all_statistics_df)
# Out:
# Processing layer: AWI_1994_DML1
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_1995_DML2
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_1996_DML3
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_1997_DML4
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_1998_DML5
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2000_DML6
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2001_DML7
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2002_DML8
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2003_DML9
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2004_DML10
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2005_ANTSYSO
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2007_ANTR
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2013_GEA-IV
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2014_Recovery-Glacier
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2015_GEA-DML
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2016_OIR
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2018_ANIRES
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2018_DML-Coast
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2018_JURAS
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: AWI_2019_JURAS
# Saved statistics for AWI to ./data_statistics/statistics_AWI.csv
# Processing layer: BAS_1994_Evans
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_1998_Dufek
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2001_Bailey-Slessor
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2001_MAMOG
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2002_TORUS
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2007_Lake-Ellsworth
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2007_Rutford
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2007_TIGRIS
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2008_Lake-Ellsworth
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2009_FERRIGNO
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2010_PIG
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2011_Adelaide
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2012_Castle
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2013_ISTAR
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2018_Thwaites
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_2019_Thwaites
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BEDMAP1_BEDMAP1
# Saved statistics for BEDMAP1 to ./data_statistics/statistics_BEDMAP1.csv
# Processing layer: BGR_1999_GANOVEX-VIII-Matusevich
# Saved statistics for BGR to ./data_statistics/statistics_BGR.csv
# Processing layer: BGR_1999_GANOVEX-VIII-Mertz
# Saved statistics for BGR to ./data_statistics/statistics_BGR.csv
# Processing layer: BGR_2002_PCMEGA
# Saved statistics for BGR to ./data_statistics/statistics_BGR.csv
# Processing layer: CECS_2006_Subglacial-Lake-CECs
# Saved statistics for CECS to ./data_statistics/statistics_CECS.csv
# Processing layer: INGV_1997_ITASE
# Saved statistics for INGV to ./data_statistics/statistics_INGV.csv
# Processing layer: INGV_1997_Talos-Dome
# Saved statistics for INGV to ./data_statistics/statistics_INGV.csv
# Processing layer: INGV_1999_Talos-Dome
# Saved statistics for INGV to ./data_statistics/statistics_INGV.csv
# Processing layer: INGV_2001_Talos-Dome
# Saved statistics for INGV to ./data_statistics/statistics_INGV.csv
# Processing layer: INGV_2003_Talos-Dome
# Saved statistics for INGV to ./data_statistics/statistics_INGV.csv
# Processing layer: KOPRI_2017_KRT1
# Saved statistics for KOPRI to ./data_statistics/statistics_KOPRI.csv
# Processing layer: KOPRI_2018_KRT2
# Saved statistics for KOPRI to ./data_statistics/statistics_KOPRI.csv
# Processing layer: LDEO_2007_Recovery-Lakes
# Saved statistics for LDEO to ./data_statistics/statistics_LDEO.csv
# Processing layer: LDEO_2015_ROSETTA
# Saved statistics for LDEO to ./data_statistics/statistics_LDEO.csv
# Processing layer: NASA_2002_ICEBRIDGE
# Saved statistics for NASA to ./data_statistics/statistics_NASA.csv
# Processing layer: NIPR_1992_JARE33
# Saved statistics for NIPR to ./data_statistics/statistics_NIPR.csv
# Processing layer: NIPR_1996_JARE37
# Saved statistics for NIPR to ./data_statistics/statistics_NIPR.csv
# Processing layer: NIPR_1999_JARE40
# Saved statistics for NIPR to ./data_statistics/statistics_NIPR.csv
# Processing layer: NIPR_2007_JARE49
# Saved statistics for NIPR to ./data_statistics/statistics_NIPR.csv
# Processing layer: NIPR_2007_JASE
# Saved statistics for NIPR to ./data_statistics/statistics_NIPR.csv
# Processing layer: NIPR_2012_JARE54
# Saved statistics for NIPR to ./data_statistics/statistics_NIPR.csv
# Processing layer: NIPR_2017_JARE59
# Saved statistics for NIPR to ./data_statistics/statistics_NIPR.csv
# Processing layer: NIPR_2018_JARE60
# Saved statistics for NIPR to ./data_statistics/statistics_NIPR.csv
# Processing layer: NPI_2008_BELISSIMA
# Saved statistics for NPI to ./data_statistics/statistics_NPI.csv
# Processing layer: NPI_2010_SRM
# Saved statistics for NPI to ./data_statistics/statistics_NPI.csv
# Processing layer: NPI_2012_ICERISES
# Saved statistics for NPI to ./data_statistics/statistics_NPI.csv
# Processing layer: NPI_2015_POLARGAP
# Saved statistics for NPI to ./data_statistics/statistics_NPI.csv
# Processing layer: NPI_2016_MADICE
# Saved statistics for NPI to ./data_statistics/statistics_NPI.csv
# Processing layer: PRIC_2004_CHINARE-21
# Saved statistics for PRIC to ./data_statistics/statistics_PRIC.csv
# Processing layer: PRIC_2007_CHINARE-24
# Saved statistics for PRIC to ./data_statistics/statistics_PRIC.csv
# Processing layer: PRIC_2015_CHA1
# Saved statistics for PRIC to ./data_statistics/statistics_PRIC.csv
# Processing layer: PRIC_2016_CHA2
# Saved statistics for PRIC to ./data_statistics/statistics_PRIC.csv
# Processing layer: PRIC_2017_CHA3
# Saved statistics for PRIC to ./data_statistics/statistics_PRIC.csv
# Processing layer: PRIC_2018_CHA4
# Saved statistics for PRIC to ./data_statistics/statistics_PRIC.csv
# Processing layer: RNRF_1971_Lambert-Amery
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_1975_Filchner-Ronne
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_1975_Lazarev
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2003_48RAEap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2003_AMSap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2004_49RAEap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2004_AMSap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2004_Mirny-Vostok
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2005_50RAEap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2005_AMSap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2006_51RAEap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2006_KV1-area
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2006_Komsom-Vostok
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2006_RAEap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2007_52RAEap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2007_AMSap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2007_Mirny-Vostok
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2008_53RAEap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2008_AMSap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2008_Vostok-Subglacial-Lake
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2009_RAEap5
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2010_RAE
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2011_RAE
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2013_RAE
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2013_Vostok-Progress
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2014_RAE
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2015_RAE
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2016_RAE
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2017_RAE
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2018_RAE
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: RNRF_2019_RAE
# Saved statistics for RNRF to ./data_statistics/statistics_RNRF.csv
# Processing layer: STOLAF_1994_Siple-Dome
# Saved statistics for STOLAF to ./data_statistics/statistics_STOLAF.csv
# Processing layer: STOLAF_2001_ITASE-Byrd-Ellsworth
# Saved statistics for STOLAF to ./data_statistics/statistics_STOLAF.csv
# Processing layer: STOLAF_2001_ITASE-Ellsworth
# Saved statistics for STOLAF to ./data_statistics/statistics_STOLAF.csv
# Processing layer: STOLAF_2002_ITASE-Byrd-South-Pole
# Saved statistics for STOLAF to ./data_statistics/statistics_STOLAF.csv
# Processing layer: STOLAF_2002_ITASE-Hercules-Dome
# Saved statistics for STOLAF to ./data_statistics/statistics_STOLAF.csv
# Processing layer: UCANTERBURY_2008_Darwin-Hatherton
# Saved statistics for UCANTERBURY to ./data_statistics/statistics_UCANTERBURY.csv
# Processing layer: ULB_2012_BEWISE
# Saved statistics for ULB to ./data_statistics/statistics_ULB.csv
# Processing layer: ULB_2012_ICECON
# Saved statistics for ULB to ./data_statistics/statistics_ULB.csv
# Processing layer: UTIG_1991_CASERTZ
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: UTIG_1998_West-Marie-Byrd-Land
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: UTIG_1999_SOAR-LVS-WLK
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: UTIG_2000_Robb-Glacier
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: UTIG_2008_ICECAP
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: UTIG_2009_Darwin-Hatherton
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: UTIG_2010_ICECAP
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: UTIG_2013_GIMBLE
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: UWASHINGTON_2018_South-Pole-Lake
# Saved statistics for UWASHINGTON to ./data_statistics/statistics_UWASHINGTON.csv
# Processing layer: AGAP
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BBAS
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: FISS2015
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: FISS2016
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: GRADES_IMAGE
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: ICEGRAV
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: IMAFI
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: ITGC_2019
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: POLARGAP
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: WISE_ISODYN
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: 2002_Antarctica_P3chile
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2004_Antarctica_P3chile
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2005_Antarctica_GPRWAIS
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2009_Antarctica_DC8
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2009_Antarctica_TO
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2009_Antarctica_TO_Gambit
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2010_Antarctica_DC8
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2011_Antarctica_DC8
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2011_Antarctica_TO
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2012_Antarctica_DC8
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2013_Antarctica_Basler
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2013_Antarctica_P3
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2014_Antarctica_DC8
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2016_Antarctica_DC8
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2017_Antarctica_Basler
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2017_Antarctica_P3
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2018_Antarctica_DC8
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2018_Antarctica_Ground
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: 2019_Antarctica_GV
# Saved statistics for CRESIS to ./data_statistics/statistics_CRESIS.csv
# Processing layer: KRT1
# Saved statistics for KOPRI to ./data_statistics/statistics_KOPRI.csv
# Processing layer: AGAP_GAMBIT
# Saved statistics for LDEO to ./data_statistics/statistics_LDEO.csv
# Processing layer: AGASEA
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: DVD
# Processing layer: EAGLE
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: ICECAP
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: LIV
# Processing layer: OIA
# Saved statistics for UTIG to ./data_statistics/statistics_UTIG.csv
# Processing layer: STI
# Processing layer: TAM
# Processing layer: WAG
# Processing layer: BAS_1969_1970
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_1971_1972
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_1974_1975
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_1980_1981
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_1982_1983
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_1983_1984
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_1984_1985
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_1985_1986
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: BAS_1987_1988
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Processing layer: STANFORD_SPRI_NSF_TUD
# Saved statistics for STANFORD to ./data_statistics/statistics_STANFORD.csv
# Skipping layer institutions as it does not contain 'institution' column.
# Skipping layer data_formats as it does not contain 'institution' column.
# Skipping layer download_methods as it does not contain 'institution' column.
# Processing layer: campaigns
# Saved statistics for BAS to ./data_statistics/statistics_BAS.csv
# Skipping layer granules as it does not contain 'institution' column.
# Saved institution overview statistics to ./data_statistics/institution_overview.csv
#
# Institution Overview Statistics:
#     institution  total_distance_km  available_distance_km
# 0           AWI          375144.05                   0.00
# 1           BAS          486941.65              282115.04
# 2       BEDMAP1         2659484.14                   0.00
# 3           BGR         5354006.88                   0.00
# 4          CECS            2121.45                   0.00
# 5        CRESIS          447236.20              447236.20
# 6          INGV          809764.41                   0.00
# 7         KOPRI           14338.95                4688.96
# 8          LDEO          106748.05               32787.93
# 9          NASA           12595.43                   0.00
# 10         NIPR         1504193.82                   0.00
# 11          NPI            8362.09                   0.00
# 12         PRIC          246609.13                   0.00
# 13         RNRF         7744467.74                   0.00
# 14     STANFORD          116345.50                   0.00
# 15       STOLAF            2781.83                   0.00
# 16  UCANTERBURY             413.78                   0.00
# 17          ULB             381.54                   0.00
# 18         UTIG         2082364.41              287161.38
# 19  UWASHINGTON             186.31                   0.00
#
# Complete statistics table:
#     institution       campaign  total_distance_km  available_distance_km
# 0           AWI      1994_DML1           21400.77                    0.0
# 1           AWI      1995_DML2           30090.50                    0.0
# 2           AWI      1996_DML3           14867.20                    0.0
# 3           AWI      1997_DML4           22635.81                    0.0
# 4           AWI      1998_DML5           19252.58                    0.0
# ..          ...            ...                ...                    ...
# 159         BAS  BAS_1984_1985           20774.86                    0.0
# 160         BAS  BAS_1985_1986           15078.41                    0.0
# 161         BAS  BAS_1987_1988           12540.76                    0.0
# 162    STANFORD   SPRI_NSF_TUD          116345.50                    0.0
# 163         BAS        Unknown               0.00                    0.0
#
# [164 rows x 4 columns]
# /var/folders/vv/czt16t1x4_12h0xsl6rcd5_80000gn/T/ipykernel_25674/79081495.py:116: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_statistics_df = pd.concat(all_statistics, ignore_index=True)
